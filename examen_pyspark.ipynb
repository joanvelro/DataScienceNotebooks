# %% [markdown]
# # Examen PySpark

# %% [markdown]
# Instrucciones: Lea cuidadosamente las preguntas, escriba el código correspondiente y ejecútelo para mostrar sus resultados.

# %% [markdown]
# #### Importante: Todos los ejercicios deberán realizarse con funciones de NumPy, Pandas o PySpark (no podrán crearse vistas temporales para realizarse en SQL, salvo que se indique lo contrario).

# %% [markdown]
# ## Bloque 1: Spark Core

# %% [markdown]
# 1.1 Utilizando NumPy, construya un arreglo con 50 elementos aleatorios distribuidos de forma normal con media 50 y desviación estándar 10. Imprima el arreglo.

# %%
import numpy as np
a = np.random.normal(50,10,50)
print(a)
# Out:
# [46.68597356 60.27889096 51.4991626  53.85460247 51.42483403 41.32348817
#  52.33762403 40.76814762 51.20321107 47.55103376 67.21286043 48.91218279
#  60.72341828 44.45399277 48.81834741 51.41674533 42.43241915 43.86230974
#  50.49106629 53.11868731 42.68446032 48.3285161  53.77199998 67.65491547
#  70.69740588 28.77237048 69.55877671 46.87041925 47.8080914  62.89884659
#  41.41749378 50.68619923 59.92524241 45.75604801 44.88180883 53.99683791
#  51.21355136 48.03194075 63.88806166 47.30527233 62.45584082 69.22371252
#  50.7975978  51.35721223 42.24371811 36.71406685 62.64319399 52.28815142
#  62.93426919 39.33521336]

# %% [markdown]
# 1.2. Construya el objeto de Spark (Core) que le permita trabajar con objetos RDD.

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading https://files.pythonhosted.org/packages/f0/26/198fc8c0b98580f617cb03cb298c6056587b8f0447e20fa40c5b634ced77/pyspark-3.0.1.tar.gz (204.2MB)
#      |████████████████████████████████| 204.2MB 64kB/s
# Collecting py4j==0.10.9
#   Downloading https://files.pythonhosted.org/packages/9e/b6/6a4fb90cd235dc8e265a6a2067f2a2c99f0d91787f06aca4bcf7c23f3f80/py4j-0.10.9-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 41.4MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.0.1-py2.py3-none-any.whl size=204612242 sha256=d1a1e98f51c0ac69e02c0c79c821ef6efd22ac7b276be2826379f298a9bda936
#   Stored in directory: /root/.cache/pip/wheels/5e/bd/07/031766ca628adec8435bb40f0bd83bb676ce65ff4007f8e73f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9 pyspark-3.0.1

# %%
from pyspark.sql import SQLContext
from pyspark import SparkContext
from pyspark.sql import SparkSession
spark = SparkSession \
        .builder \
        .appName("Python Spark SQL") \
        .config("spark.some.config.option", "some-value") \
        .getOrCreate()
#print(spark.version)
sqlContext = SQLContext(spark)
#print(sqlContext)
sc = spark.sparkContext
print(sc)
# Out:
# <SparkContext master=local[*] appName=Python Spark SQL basic example>

# %% [markdown]
# 1.3. Convierta el arreglo de NumPy a un RDD con 2 particiones. Muestre los primeros 5 elementos.

# %%
# Convert list to RDD
rdd = sc.parallelize(a)

rdd.top(5)
# Out:
# [70.69740588157727,
#  69.55877670948394,
#  69.22371251958063,
#  67.65491546838084,
#  67.21286043416487]

# %% [markdown]
# 1.4. Suponiendo que los datos de la lista miden grados Fahrenheit, aplique una función lambda al RDD que convierta las mediciones a grados Centígrados. Muestre los primeros 5 elementos.
# $$
# C = (F - 32) * 5 / 9
# $$

# %%
rdd = rdd.map(lambda degree: (degree-32)*5/9)

rdd.top(5)
# Out:
# [21.49855882309848,
#  20.86598706082441,
#  20.679840288655907,
#  19.808286371322687,
#  19.562700241202705]

# %% [markdown]
# 1.5. Utilice una función Lambda para mostrar únicamente las temperaturas mayores a 15 grados Centigrados.

# %%
rdd.filter(lambda degree: degree>15).collect()
# Out:
# [15.710494976670573,
#  19.562700241202705,
#  15.957454600267674,
#  19.808286371322687,
#  21.49855882309848,
#  20.86598706082441,
#  17.16602588066187,
#  15.514023561704285,
#  17.71558981312119,
#  16.919911567083236,
#  20.679840288655907,
#  17.023996661949997,
#  17.185705103208576]

# %% [markdown]
# 1.6. Calcule la temperatura media en grados Centígrados.

# %%
rdd.mean()
# Out:
# 10.939002583177448

# %% [markdown]
# 1.7. Obtenga las 3 temperaturas más altas en grados Centígrados.

# %%
rdd.sortBy(lambda x: -x).top(3)
# Out:
# [21.49855882309848, 20.86598706082441, 20.679840288655907]

# %% [markdown]
# ## Bloque 2: Spark SQL

# %% [markdown]
# 2.1. Utilizando Numpy, construya un arreglo con 50 números enteros entre 1 y 3 (1 y 3 incluidos).

# %%
b = np.random.uniform(1,3+1,50).astype(int)
print(b)
# Out:
# [1 1 1 3 2 1 1 1 3 1 1 1 3 1 1 1 2 3 1 1 2 1 1 2 2 1 2 3 2 3 1 1 1 2 3 3 2
#  3 2 3 2 3 2 1 3 3 3 2 1 2]

# %% [markdown]
# 2.2. Construya un dataframe en Pandas utilizando los arreglos de 2.1 y 1.1. Asigne los nombres "dia" y "temp". Muestre los primeros 5 elementos.

# %%
import pandas as pd
df = pd.DataFrame({'dia':b, 'temp':a})
df.head(5)
# Out:
#    dia       temp
# 0    1  46.685974
# 1    1  60.278891
# 2    1  51.499163
# 3    3  53.854602
# 4    2  51.424834

# %% [markdown]
# 2.3. Construya el objeto de Spark (SQL) que le permita trabajar con los dataframes de Spark.

# %%
#from pyspark import SparkContext
from pyspark.sql.types import *
from pyspark.sql import SparkSession
spark = SparkSession \
        .builder \
        .appName("Python Spark SQL") \
        .config("spark.some.config.option", "some-value") \
        .getOrCreate()
#print(spark.version)
#sqlContext = SQLContext(spark)

# %% [markdown]
# 2.4. Convierta el dataframe de Pandas a un dataframe de Spark, definiendo explícitamente el esquema/estructura (utilice el tipo entero para el día y el tipo doble para la temperatura). Muestre los primeros 5 registros.

# %%
schemaString = "dia temp"
fields = [StructField(field_name, StringType(), True) for field_name in schemaString.split()]
schema = StructType(fields)
spark.createDataFrame(df, schema).show()
# Out:
# +---+------------------+
# |dia|              temp|
# +---+------------------+
# |  1| 46.68597355698461|
# |  1| 60.27889095800703|
# |  1| 51.49916259850273|
# |  3| 53.85460246606196|
# |  2| 51.42483403115909|
# |  1| 41.32348816662592|
# |  1|52.337624032830476|
# |  1| 40.76814762025096|
# |  3| 51.20321107476273|
# |  1| 47.55103375589605|
# |  1| 67.21286043416487|
# |  1| 48.91218278568232|
# |  3|60.723418280481816|
# |  1|44.453992773368725|
# |  1|48.818347406069904|
# |  1| 51.41674533222415|
# |  2| 42.43241915019395|
# |  3| 43.86230974086338|
# |  1| 50.49106629058457|
# |  1|  53.1186873065882|
# +---+------------------+
# only showing top 20 rows

# %%
from pyspark import SparkContext
#sc = SparkContext()
from pyspark.sql import SQLContext
#from pyspark.sql import SQLContext
sqlCtx = SQLContext(sc)
sdf = sqlCtx.createDataFrame(df)

# %% [markdown]
# 2.5. Partiendo del dataframe en Spark, construya un dataframe con el promedio de temperatura agrupado por día. El dataframe deberá contener únicamente las columnas "dia" y "temp_prom" (con esos nombres). Muestre la tabla resultante.

# %%
sdf.groupBy('dia').mean().select('dia','avg(temp)').withColumnRenamed('avg(temp)', 'temp_prom').show()
# Out:
# +---+------------------+
# |dia|         temp_prom|
# +---+------------------+
# |  1|50.093704836872284|
# |  3|51.746668477497714|
# |  2| 54.14252624212942|
# +---+------------------+

# %% [markdown]
# 2.6. Repita el ejercicio anterior registrando una vista temporal y ejecutando el código SQL correspondiente. Muestre la tabla resultante.

# %%
sdf.createGlobalTempView("temp")

# %%
spark.sql("SELECT dia, AVG(temp) as temp_prom FROM global_temp.temp GROUP BY dia").show()
# Out:
# +---+------------------+
# |dia|         temp_prom|
# +---+------------------+
# |  1|50.093704836872284|
# |  3|51.746668477497714|
# |  2| 54.14252624212942|
# +---+------------------+

# %% [markdown]
# 2.7. Combine los valores del dataframe anterior con el original. El dataframe resultante no deberá contener columnas repetidas y tendrá que estar ordenado de forma ascendente por día y temperatura. Muestre los primeros 5 elementos.

# %%
spark.sql("SELECT T.dia, T.temp FROM global_temp.temp as T LEFT JOIN (SELECT dia, AVG(temp) FROM global_temp.temp GROUP BY dia) A ORDER BY dia, temp ASC").show(5)
# Out:
# +---+-----------------+
# |dia|             temp|
# +---+-----------------+
# |  1|28.77237047932717|
# |  1|28.77237047932717|
# |  1|28.77237047932717|
# |  1|40.76814762025096|
# |  1|40.76814762025096|
# +---+-----------------+
# only showing top 5 rows

# %% [markdown]
# 2.8. Añada una columna adicicional con la diferencia entre la temperatura y su media. Asigne el nombre "resid". Muestre los primeros 5 elementos.

# %% [markdown]
# 2.9. Construya un dataframe con todos los registros que posean residuales negativos. Muestre los primeros 5 elementos.

# %%
df_temp = sqlContext.sql("SELECT * FROM global_temp.temp")

# %% [markdown]
# 2.10. Guarde el dataframe resultante en formato JSON. En caso de que el archivo ya exista, deberá sobreescribirse.

# %%
df_temp.select("temp", "dia").write.save("temp.json",format="json")

# %% [markdown]
# ## Bloque 3: Spark MLlib

# %% [markdown]
# #### En esta sección se evalúan los conocimientos de Spark MLlib. Si bien son necesarios los conociemientos en Machine Learning, el candidato no será evaluado por la calidad del modelo producido.

# %% [markdown]
# 3.1. Cargue los datos del archivo 'data.csv'.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_data = spark.read.format("csv").option("header", "true").load("data.csv")

# %% [markdown]
# 3.2. Realicé un análisis exploratorio preliminar de los datos (estadísticos básicos de las columnas).

# %%
df_data.describe().show()
# Out:
# +-------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+--------------------+--------------------+-------------------+
# |summary|        Names|              Age|   Total_Purchase|   Account_Manager|            Years|         Num_Sites|       Onboard_date|            Location|             Company|              Churn|
# +-------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+--------------------+--------------------+-------------------+
# |  count|          900|              900|              900|               900|              900|               900|                900|                 900|                 900|                900|
# |   mean|         null|41.81666666666667|10062.82403333334|0.4811111111111111| 5.27315555555555| 8.587777777777777|               null|                null|                null|0.16666666666666666|
# | stddev|         null|6.127560416916251|2408.644531858096|0.4999208935073339|1.274449013194616|1.7648355920350969|               null|                null|                null| 0.3728852122772358|
# |    min|   Aaron King|             22.0|            100.0|                 0|              1.0|              10.0|2006-01-02 04:16:13|00103 Jeffrey Cre...|     Abbott-Thompson|                  0|
# |    max|Zachary Walsh|             65.0|           9993.5|                 1|             9.15|               9.0|2016-12-28 04:07:38|Unit 9800 Box 287...|Zuniga, Clark and...|                  1|
# +-------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+--------------------+--------------------+-------------------+

# %% [markdown]
# 3.3. Obtenga el conjunto de datos con el vector de variables independientes y la variable dependiente (churn). Por simplicidad, es suficiente que seleccione únicamente las variables numéricas. Muestre los primeros 5 elementos.

# %%
X = df_data.select('Age','Total_Purchase','Account_Manager','Years', 'Num_Sites')
X.show(5)
# Out:
# +----+--------------+---------------+-----+---------+
# | Age|Total_Purchase|Account_Manager|Years|Num_Sites|
# +----+--------------+---------------+-----+---------+
# |42.0|       11066.8|              0| 7.22|      8.0|
# |41.0|      11916.22|              0|  6.5|     11.0|
# |38.0|      12884.75|              0| 6.67|     12.0|
# |42.0|       8010.76|              0| 6.71|     10.0|
# |37.0|       9191.58|              0| 5.56|      9.0|
# +----+--------------+---------------+-----+---------+
# only showing top 5 rows

# %%
df_data.select('Churn')
y.show(5)
# Out:
# +-----+
# |Churn|
# +-----+
# |    1|
# |    1|
# |    1|
# |    1|
# |    1|
# +-----+
# only showing top 5 rows

# %% [markdown]
# 3.4. Realicé la separación en los conjuntos de entrenamiento y prueba con una proporción 70-30. Muestre los primeros 5 elementos de cada conjunto de datos.

# %%
train, test = df_data.randomSplit([0.7, 0.3], seed=12345)
X_train = train.select('Names','Onboard_date','Company','Location','Age','Total_Purchase','Account_Manager','Years', 'Num_Sites')
X_test = train.select('Names','Onboard_date','Company','Location','Age','Total_Purchase','Account_Manager','Years', 'Num_Sites')
y_train = train.select('Churn')
y_test= train.select('Churn')

# %% [markdown]
# 3.5. Ajuste un modelo de regresión logística con los hiperparámetros por defecto. Muestre los estadísticos descriptivos de las predicciones contenidas en el resumen del modelo.

# %%
from pyspark.ml.classification import LogisticRegression

# %%
X_train.toPandas().values.tolist()
# Out:
# [['Aaron King',
#   '2007-05-13 20:42:11',
#   'Hernandez PLC',
#   '38346 Smith Prairie Arnoldside, MD 33861-4885',
#   '46.0',
#   '7504.79',
#   '0',
#   '5.98',
#   '8.0'],
#  ['Aaron Meyer',
#   '2010-07-17 03:30:38',
#   'Steele, Bates and Lane',
#   '35821 Bailey Skyway Alexisstad, NH 81472',
#   '45.0',
#   '9598.03',
#   '0',
#   '5.0',
#   '7.0'],
#  ['Aaron West',
#   '2006-09-01 06:11:47',
#   'Cruz, Russell and Boyd',
#   '071 Schmidt Locks Apt. 070 West Jessica, OK 60879-6593',
#   '55.0',
#   '10056.55',
#   '0',
#   '4.98',
#   '8.0'],
#  ['Abigail Gonzalez',
#   '2014-01-09 19:52:37',
#   'Nelson PLC',
#   '325 Lawrence Crossing Suite 269 South Josephhaven, OK 53193-5178',
#   '55.0',
#   '8243.28',
#   '0',
#   '3.54',
#   '6.0'],
#  ['Abigail Jennings',
#   '2012-03-11 17:10:26',
#   'Simpson, Byrd and Miller',
#   'USS Mcgrath FPO AP 33786-7308',
#   '36.0',
#   '12309.23',
#   '1',
#   '4.76',
#   '9.0'],
#  ['Adam Gomez',
#   '2013-02-06 05:15:06',
#   'Thompson Group',
#   '2889 Coffey Parks Browningmouth, VT 14924-9744',
#   '48.0',
#   '6495.01',
#   '1',
#   '5.57',
#   '12.0'],
#  ['Adam Moore',
#   '2010-01-22 19:08:48',
#   'Little, White and Davis',
#   '339 Jeffrey River Suite 638 Fergusonville, DC 25987',
#   '41.0',
#   '12659.88',
#   '0',
#   '4.55',
#   '4.0'],
#  ['Adam Porter',
#   '2006-02-18 01:22:53',
#   'Anthony-Wood',
#   '92600 Kevin Cape South Sandraberg, NH 47456-5208',
#   '48.0',
#   '10746.37',
#   '1',
#   '4.22',
#   '8.0'],
#  ['Adam Strong',
#   '2011-02-06 15:02:27',
#   'Harvey-Mcdowell',
#   '33071 Melody Isle East Matthew, WV 08980-8853',
#   '50.0',
#   '11775.75',
#   '1',
#   '4.83',
#   '10.0'],
#  ['Adam Waters',
#   '2006-03-06 18:36:47',
#   'Reed Ltd',
#   '6040 Juan Forge Parrishville, NJ 27948',
#   '40.0',
#   '11185.62',
#   '0',
#   '6.26',
#   '12.0'],
#  ['Adriana James',
#   '2016-04-09 09:02:14',
#   'Doyle, Butler and Coleman',
#   'USNV Ferguson FPO AP 58507',
#   '36.0',
#   '10448.09',
#   '0',
#   '4.13',
#   '8.0'],
#  ['Alan Gray',
#   '2013-02-19 03:23:16',
#   'Mendoza Inc',
#   '9278 Jenna Ways Apt. 628 West Ryan, AZ 06819-5978',
#   '29.0',
#   '9617.59',
#   '0',
#   '5.49',
#   '8.0'],
#  ['Alex Banks',
#   '2016-09-18 16:37:16',
#   'Jones-Meyers',
#   '2109 Moore Lights North Heatherberg, NY 99942',
#   '36.0',
#   '8918.52',
#   '0',
#   '3.62',
#   '8.0'],
#  ['Alexandra Phillips',
#   '2009-03-26 05:25:30',
#   'Smith, Harris and Black',
#   '078 Ortega Vista Lake Gabriella, OK 18890-5973',
#   '32.0',
#   '9472.72',
#   '1',
#   '1.0',
#   '10.0'],
#  ['Alexis Allen',
#   '2016-09-27 07:00:35',
#   'Jones and Sons',
#   '7448 Jason Ridges Heatherfort, GU 92916-6774',
#   '43.0',
#   '7686.13',
#   '1',
#   '7.17',
#   '8.0'],
#  ['Allison Clark DDS',
#   '2006-07-11 11:32:51',
#   'Robinson-Perez',
#   'PSC 9202, Box 1991 APO AA 75619',
#   '43.0',
#   '14241.75',
#   '0',
#   '3.73',
#   '12.0'],
#  ['Alyssa Harper DDS',
#   '2006-09-04 07:20:52',
#   'Garza-Alexander',
#   '63593 Hector Mission South Williambury, IA 79862-2416',
#   '45.0',
#   '9874.69',
#   '1',
#   '2.41',
#   '9.0'],
#  ['Alyssa Pitts',
#   '2014-07-13 21:28:58',
#   'Smith, Anderson and Reyes',
#   '881 Neal Mill Apt. 098 West Alexandra, RI 98586-9878',
#   '45.0',
#   '10976.03',
#   '0',
#   '4.5',
#   '10.0'],
#  ['Amanda Barnett',
#   '2009-06-04 09:14:47',
#   'Lee Ltd',
#   '205 Campbell Highway Port Wyatt, AK 84887-4000',
#   '45.0',
#   '9773.22',
#   '1',
#   '3.79',
#   '10.0'],
#  ['Amanda Brown',
#   '2008-05-30 03:35:34',
#   'Hoffman Ltd',
#   '48681 Jensen Vista South Kevin, ND 80285',
#   '32.0',
#   '12403.6',
#   '0',
#   '4.99',
#   '7.0'],
#  ['Amanda Hernandez',
#   '2015-05-31 21:15:18',
#   'Barry, Brown and Smith',
#   '4792 Amy Wall Apt. 296 Olsenchester, VA 69141-5857',
#   '38.0',
#   '10298.29',
#   '1',
#   '5.07',
#   '9.0'],
#  ['Amanda Wade',
#   '2011-03-05 06:46:38',
#   'Jordan, Beasley and Moore',
#   '869 Kathleen Dam Apt. 113 East Robertshire, SC 50012-1080',
#   '39.0',
#   '8880.17',
#   '0',
#   '4.0',
#   '8.0'],
#  ['Amanda Williams',
#   '2011-07-07 15:43:46',
#   'Jones-Fisher',
#   '79676 Johnson Villages Apt. 089 Reyesstad, DC 78510',
#   '37.0',
#   '8614.75',
#   '0',
#   '5.03',
#   '9.0'],
#  ['Amber Carr',
#   '2012-07-03 18:49:25',
#   'Davis, Mccormick and Carson',
#   '95266 Mary Fort West Kennethmouth, WV 43523',
#   '44.0',
#   '10965.95',
#   '1',
#   '4.11',
#   '8.0'],
#  ['Amber Hobbs',
#   '2013-03-28 20:04:50',
#   'Nelson, Ray and Johnson',
#   '8044 Bates Spring Jonesborough, LA 63728',
#   '43.0',
#   '10400.88',
#   '0',
#   '5.84',
#   '10.0'],
#  ['Amber Martin',
#   '2009-02-24 20:56:56',
#   'Kelly-Greene',
#   '5487 Rodriguez Fork Ballberg, MP 65143-5880',
#   '40.0',
#   '8083.76',
#   '0',
#   '4.76',
#   '7.0'],
#  ['Amber Spears',
#   '2008-07-26 03:00:31',
#   'Gray Inc',
#   '455 Garcia Via Suite 177 Lake Jefferyside, MN 81187',
#   '41.0',
#   '13365.66',
#   '1',
#   '8.36',
#   '9.0'],
#  ['Amber Williams',
#   '2012-03-02 18:33:21',
#   'Lee, Daniels and Ryan',
#   '2896 Diana Spur Suite 985 New Tami, IN 56915',
#   '40.0',
#   '8530.23',
#   '1',
#   '3.66',
#   '10.0'],
#  ['Amy Baldwin',
#   '2009-11-01 10:37:02',
#   'Morgan-Garcia',
#   '596 Erica Route Apt. 258 New Janice, IN 57273',
#   '41.0',
#   '13743.42',
#   '0',
#   '3.92',
#   '9.0'],
#  ['Amy Garcia',
#   '2007-03-09 23:50:39',
#   'Barker Ltd',
#   '12223 Sean Valley Suite 960 Johnland, IA 33208',
#   '42.0',
#   '6406.38',
#   '0',
#   '3.0',
#   '9.0'],
#  ['Amy Henderson',
#   '2011-02-07 17:54:22',
#   'Knox-Davis',
#   '85837 Thomas Dam Nicholasview, MT 98793-4972',
#   '31.0',
#   '10058.87',
#   '1',
#   '6.54',
#   '7.0'],
#  ['Amy Morris',
#   '2015-04-01 19:58:01',
#   'Patel, Smith and Campos',
#   '017 Gutierrez Fork New Benjamin, VA 99400',
#   '45.0',
#   '9951.97',
#   '1',
#   '4.4',
#   '6.0'],
#  ['Amy Riddle',
#   '2009-08-19 08:06:04',
#   'Parker PLC',
#   '4964 Page Estate East Richardmouth, OK 43652',
#   '45.0',
#   '8389.84',
#   '1',
#   '6.81',
#   '5.0'],
#  ['Amy Stanley',
#   '2010-10-15 11:16:01',
#   'Johnson-Nelson',
#   '906 Kelly Courts Suite 424 Lake Michaelborough, NV 63970',
#   '43.0',
#   '9060.28',
#   '1',
#   '4.95',
#   '6.0'],
#  ['Ana Smith',
#   '2014-06-20 05:10:09',
#   'Schneider-Smith',
#   'Unit 8633 Box 8738 DPO AA 14126-5026',
#   '45.0',
#   '12056.18',
#   '0',
#   '5.46',
#   '4.0'],
#  ['Andrea Ford',
#   '2010-10-08 22:11:05',
#   'Patton Group',
#   '2519 Martin Ports Suite 635 Martinport, AL 55438',
#   '40.0',
#   '11362.95',
#   '0',
#   '4.37',
#   '11.0'],
#  ['Andrea George',
#   '2014-09-19 08:46:46',
#   'Johnson, Fields and Anderson',
#   '9089 Jennifer Brooks Suite 571 New Lisa, WA 53342-5359',
#   '43.0',
#   '12691.45',
#   '0',
#   '4.45',
#   '11.0'],
#  ['Andrea Ortiz',
#   '2009-01-12 14:37:14',
#   'Barron, Tapia and Black',
#   '7645 Huff Lights Suite 209 Stephenmouth, GA 01888',
#   '40.0',
#   '9521.35',
#   '0',
#   '5.8',
#   '9.0'],
#  ['Andrea Salas',
#   '2015-03-19 22:32:48',
#   'Blackwell PLC',
#   '308 Graham Corners Valeriehaven, SC 12062',
#   '42.0',
#   '11473.38',
#   '1',
#   '2.87',
#   '10.0'],
#  ['Andrea Warner',
#   '2011-03-24 17:01:00',
#   'Bailey LLC',
#   '753 Hernandez Pines Apt. 505 North Manuelstad, MI 14141-9782',
#   '46.0',
#   '10469.5',
#   '0',
#   '6.54',
#   '10.0'],
#  ['Andrew Hester',
#   '2007-09-18 14:11:53',
#   'Woodward-Bruce',
#   '614 Wilson Extensions New Richardshire, AK 59247',
#   '48.0',
#   '11555.21',
#   '1',
#   '4.45',
#   '8.0'],
#  ['Andrew Kent',
#   '2011-12-24 17:00:01',
#   'Briggs, Cross and Norris',
#   '79904 Jacobson Wells Apt. 852 Josephfort, NV 94414',
#   '45.0',
#   '12374.97',
#   '0',
#   '4.66',
#   '7.0'],
#  ['Andrew Moreno',
#   '2008-03-28 21:32:43',
#   'Williams Group',
#   '60669 Rivera Lights Suite 982 Michaelside, AK 96751',
#   '43.0',
#   '12068.39',
#   '1',
#   '3.59',
#   '7.0'],
#  ['Andrew Young',
#   '2014-04-10 03:33:41',
#   'Morris LLC',
#   '30316 Melissa Hills Apt. 368 Cynthiaborough, MN 06736',
#   '30.0',
#   '6744.87',
#   '0',
#   '5.14',
#   '9.0'],
#  ['Angela Holloway',
#   '2009-10-29 16:25:56',
#   'Ray-Rodriguez',
#   '7488 Dana Mountain Suite 133 Lake Desireeport, MD 40139-0534',
#   '40.0',
#   '12919.92',
#   '0',
#   '4.23',
#   '11.0'],
#  ['Angela Ross',
#   '2014-04-23 10:59:55',
#   'Miller-Ramirez',
#   '1008 Ricky River Port Joshua, GA 42542',
#   '39.0',
#   '13574.53',
#   '1',
#   '5.69',
#   '10.0'],
#  ['Ann Johnson',
#   '2014-03-27 05:11:22',
#   'Walker Ltd',
#   '2091 Sims Ranch Lauraborough, KS 59292-0985',
#   '42.0',
#   '9091.99',
#   '0',
#   '5.85',
#   '6.0'],
#  ['Ann White',
#   '2008-06-25 00:45:14',
#   'Hancock LLC',
#   '91968 Pena Stream Apt. 094 New Justin, GU 24101',
#   '43.0',
#   '8950.33',
#   '0',
#   '6.76',
#   '9.0'],
#  ['Anna Bryant',
#   '2007-03-18 11:14:44',
#   'Bennett Inc',
#   '30668 Isabella Freeway Suite 428 Lake Kellyhaven, MP 89074-5017',
#   '39.0',
#   '8801.86',
#   '1',
#   '4.43',
#   '10.0'],
#  ['Anna Wood',
#   '2008-08-06 05:26:39',
#   'Miranda-Sloan',
#   '33021 Cody Falls Apt. 693 Bellfort, NM 76335-9037',
#   '38.0',
#   '11360.99',
#   '0',
#   '4.5',
#   '7.0'],
#  ['Annette Taylor',
#   '2013-04-07 23:27:11',
#   'Zimmerman Group',
#   '27767 Amy Curve Lake Daniel, NM 73021-5259',
#   '41.0',
#   '10919.81',
#   '0',
#   '4.63',
#   '8.0'],
#  ['Anthony Green',
#   '2010-02-26 16:33:36',
#   'Miller, Gardner and Harris',
#   '824 Ryan Orchard Rebeccabury, FL 02869',
#   '52.0',
#   '12010.74',
#   '0',
#   '5.09',
#   '8.0'],
#  ['Anthony Hall',
#   '2011-01-24 07:40:18',
#   'Kelly Group',
#   '0910 Bell Mount West Lindseyview, MS 35802',
#   '46.0',
#   '11537.69',
#   '1',
#   '6.37',
#   '7.0'],
#  ['Anthony Molina',
#   '2007-09-22 09:46:47',
#   'Brown, Johnson and Fowler',
#   '255 Olson Mountain Maryshire, WA 83173-0377',
#   '26.0',
#   '8939.61',
#   '0',
#   '4.54',
#   '7.0'],
#  ['Anthony Mooney',
#   '2010-11-19 04:30:56',
#   'Knight-Price',
#   '9131 Russell Court Suite 160 South Michellefurt, PW 79597',
#   '41.0',
#   '9014.9',
#   '1',
#   '4.45',
#   '7.0'],
#  ['Anthony Vega',
#   '2011-08-16 19:16:12',
#   'Hall Group',
#   'PSC 9086, Box 2290 APO AP 24944-0330',
#   '44.0',
#   '9351.88',
#   '1',
#   '4.32',
#   '6.0'],
#  ['April Freeman',
#   '2011-08-28 03:41:36',
#   'Larson, Ross and Ward',
#   '16914 Oconnell Forge Apt. 477 Atkinsonmouth, MD 32666',
#   '41.0',
#   '9923.79',
#   '1',
#   '4.75',
#   '13.0'],
#  ['Ashlee Carr',
#   '2011-09-29 05:47:23',
#   'Lopez PLC',
#   '3725 Caroline Stravenue South Christineview, MA 82059',
#   '43.0',
#   '14062.6',
#   '1',
#   '5.46',
#   '11.0'],
#  ['Ashley Smith',
#   '2007-09-19 06:55:51',
#   'Jones, Reyes and Cross',
#   '663 White Tunnel Suite 995 Port Joseph, PR 93959-2444',
#   '29.0',
#   '5900.78',
#   '1',
#   '5.56',
#   '8.0'],
#  ['Ashley Soto',
#   '2012-01-01 21:48:50',
#   'Brown Inc',
#   '275 Thompson Street Lake Nathan, AS 67338-1025',
#   '49.0',
#   '9853.64',
#   '1',
#   '6.95',
#   '6.0'],
#  ['Austin Branch',
#   '2006-05-08 03:13:35',
#   'Daniels PLC',
#   '29954 Burns Lake Apt. 491 Lake Dana, KY 85990',
#   '38.0',
#   '10788.67',
#   '0',
#   '4.98',
#   '7.0'],
#  ['Austin Hays',
#   '2008-06-15 03:31:07',
#   'Austin Ltd',
#   '55004 Schmidt Fort Apt. 448 North Samanthaland, AR 63822',
#   '41.0',
#   '9516.87',
#   '0',
#   '4.94',
#   '7.0'],
#  ['Austin Palmer',
#   '2009-03-21 00:05:24',
#   'Lynch-Davies',
#   '85112 Raymond Ridge Suite 934 East Christinachester, CO 33248',
#   '36.0',
#   '9593.71',
#   '0',
#   '3.98',
#   '6.0'],
#  ['Bailey Carroll',
#   '2009-08-16 05:26:52',
#   'Lutz Inc',
#   '3738 Kiara Rue Suite 215 South Connor, VA 29347',
#   '37.0',
#   '11517.19',
#   '1',
#   '8.34',
#   '11.0'],
#  ['Barbara Singleton',
#   '2012-08-02 14:55:41',
#   'Kennedy and Sons',
#   '176 Cheryl Plains Suite 253 Harrisonmouth, PW 17373-8223',
#   '38.0',
#   '9461.83',
#   '0',
#   '4.9',
#   '10.0'],
#  ['Barbara Watkins',
#   '2014-09-17 10:05:20',
#   'Benitez, Durham and Lee',
#   '86043 Michael Ridge Lindseyland, SD 36903-4426',
#   '37.0',
#   '8316.89',
#   '0',
#   '3.6',
#   '8.0'],
#  ['Barry Gallagher',
#   '2010-06-04 12:28:32',
#   'Butler PLC',
#   '35333 Carla Keys Robinsonchester, CA 02095',
#   '52.0',
#   '6805.48',
#   '1',
#   '6.05',
#   '9.0'],
#  ['Becky Cardenas',
#   '2006-09-11 04:55:09',
#   'Lewis LLC',
#   '9103 David Drives Wilsonport, PA 79287',
#   '51.0',
#   '13762.79',
#   '0',
#   '7.52',
#   '9.0'],
#  ['Benjamin Huff',
#   '2007-03-06 12:55:46',
#   'Hurley, Moody and Gomez',
#   '205 Hall Mission Apt. 211 South Matthew, HI 81737-8521',
#   '45.0',
#   '8871.53',
#   '0',
#   '3.76',
#   '8.0'],
#  ['Benjamin Richard',
#   '2009-09-24 19:34:31',
#   'Johns, Ross and Harris',
#   '341 Horne Parks Apt. 964 Wallermouth, AZ 23035',
#   '44.0',
#   '5002.58',
#   '0',
#   '4.57',
#   '11.0'],
#  ['Beth Barnes',
#   '2014-06-30 06:15:01',
#   'Allen, Parker and Washington',
#   '763 Jillian Vista Suite 240 East Kurt, VI 53651',
#   '51.0',
#   '9764.39',
#   '1',
#   '6.03',
#   '8.0'],
#  ['Beth Fitzgerald',
#   '2008-03-24 13:32:50',
#   'Gonzalez, Gilbert and Wall',
#   '63692 Lucas Neck Apt. 112 North Kevinshire, NH 24241-9525',
#   '48.0',
#   '8863.36',
#   '0',
#   '6.35',
#   '7.0'],
#  ['Betty Bowers',
#   '2014-10-31 16:00:04',
#   'Davis Ltd',
#   '79062 Henson Expressway Williamsview, PR 54326-7935',
#   '43.0',
#   '12078.39',
#   '1',
#   '6.06',
#   '6.0'],
#  ['Beverly Hall',
#   '2007-02-23 10:47:06',
#   'Johnson, Ingram and Hart',
#   '145 Kelly Crest Apt. 419 Madelinehaven, OH 55835-0109',
#   '33.0',
#   '8556.73',
#   '0',
#   '4.21',
#   '9.0'],
#  ['Billy Garner',
#   '2009-11-06 13:24:18',
#   'Brooks Inc',
#   '68569 Sharon Centers Apt. 331 West Ryanport, FM 66389-2936',
#   '46.0',
#   '10050.61',
#   '0',
#   '4.99',
#   '7.0'],
#  ['Bobby Christian',
#   '2011-03-12 07:37:55',
#   'Freeman, Lam and Jenkins',
#   'PSC 8568, Box 1611 APO AA 56585-0874',
#   '35.0',
#   '12107.03',
#   '0',
#   '5.82',
#   '9.0'],
#  ['Bradley Chambers',
#   '2014-05-04 18:26:39',
#   'Wilson LLC',
#   'PSC 6159, Box 4526 APO AA 00585',
#   '37.0',
#   '8818.03',
#   '1',
#   '2.89',
#   '9.0'],
#  ['Bradley Washington',
#   '2016-01-01 18:31:30',
#   'Smith and Sons',
#   '149 Paula Divide Vazquezfurt, MN 57597-1890',
#   '46.0',
#   '9306.05',
#   '0',
#   '5.35',
#   '7.0'],
#  ['Brandon Ballard',
#   '2008-09-27 05:35:16',
#   'Graham-Allen',
#   '97254 Ward Stravenue North Melanie, DE 04764',
#   '43.0',
#   '9541.45',
#   '0',
#   '6.05',
#   '8.0'],
#  ['Brandon Compton',
#   '2016-07-21 02:39:27',
#   'Sanchez-Cardenas',
#   '202 Richard Extensions Apt. 994 Pamelachester, IL 73985-9604',
#   '44.0',
#   '8274.32',
#   '0',
#   '5.7',
#   '8.0'],
#  ['Brandon Ortiz',
#   '2007-12-13 12:23:32',
#   'Ewing Group',
#   '276 Thompson Field Apt. 992 South Victoriaton, SC 12848-8182',
#   '37.0',
#   '8286.87',
#   '1',
#   '6.25',
#   '8.0'],
#  ['Brenda Fuentes',
#   '2016-03-04 14:24:53',
#   'Boyd, Jennings and Gutierrez',
#   '443 Shari Plains Apt. 479 Tiffanyside, TN 88122',
#   '44.0',
#   '9214.98',
#   '1',
#   '6.44',
#   '7.0'],
#  ['Brenda Haley',
#   '2010-10-14 07:46:45',
#   'Forbes LLC',
#   'USS Barr FPO AE 09092',
#   '41.0',
#   '14069.41',
#   '1',
#   '1.62',
#   '10.0'],
#  ['Brenda Hall',
#   '2010-02-20 16:08:12',
#   'Rosales Inc',
#   '1877 Tara Streets West Sarah, MN 39500',
#   '37.0',
#   '11628.1',
#   '1',
#   '6.83',
#   '10.0'],
#  ['Brenda Ruiz',
#   '2016-11-07 08:00:39',
#   'Avery Inc',
#   '34011 Montgomery Terrace Reynoldsmouth, MI 62031-7230',
#   '44.0',
#   '7193.84',
#   '0',
#   '6.22',
#   '7.0'],
#  ['Brenda Walls',
#   '2006-05-10 04:40:16',
#   'Jones, Black and Schneider',
#   '078 Nunez Haven Suite 032 East Bradley, SC 36621-1197',
#   '51.0',
#   '10877.81',
#   '1',
#   '8.35',
#   '8.0'],
#  ['Brendan Garcia',
#   '2013-07-20 00:18:40',
#   'Arnold, Skinner and Strickland',
#   'USS Reed FPO AE 89292-3816',
#   '47.0',
#   '9101.71',
#   '0',
#   '4.11',
#   '6.0'],
#  ['Brendan Higgins',
#   '2010-12-24 13:44:30',
#   'Ballard-Allen',
#   '10155 Alison Tunnel Suite 682 Gonzalesside, GA 06335',
#   '34.0',
#   '13976.64',
#   '0',
#   '5.16',
#   '8.0'],
#  ['Brett Allen MD',
#   '2008-02-07 15:42:36',
#   'Brown-Rangel',
#   '03559 Rodriguez Prairie Apt. 826 Rachelfurt, ND 85441',
#   '45.0',
#   '12309.39',
#   '1',
#   '4.57',
#   '11.0'],
#  ['Brian Hill',
#   '2015-03-09 18:14:17',
#   'Lee, Valencia and Wood',
#   '357 Mcfarland Squares Apt. 356 West Elizabethmouth, DE 60392',
#   '37.0',
#   '9499.3',
#   '1',
#   '6.81',
#   '8.0'],
#  ['Brian Love',
#   '2010-06-15 02:58:42',
#   'Quinn and Sons',
#   '43677 Smith Mission Meganview, VA 54055',
#   '44.0',
#   '8755.02',
#   '1',
#   '5.71',
#   '8.0'],
#  ['Brian Morse',
#   '2009-05-05 04:56:19',
#   'Robinson Inc',
#   '7865 Gutierrez Expressway Suite 948 Tiffanyside, AR 59662-2367',
#   '46.0',
#   '9982.55',
#   '1',
#   '4.75',
#   '7.0'],
#  ['Brian White',
#   '2013-01-09 06:06:37',
#   'Martinez, Ochoa and Jennings',
#   'PSC 1209, Box 3739 APO AE 03896',
#   '48.0',
#   '7778.73',
#   '1',
#   '4.18',
#   '8.0'],
#  ['Brittany Green',
#   '2011-02-13 18:26:31',
#   'Smith, Stein and Mueller',
#   '1241 Wiley Motorway Prattchester, TN 32961-5246',
#   '41.0',
#   '11971.75',
#   '1',
#   '5.38',
#   '7.0'],
#  ['Brittany Hopkins',
#   '2010-02-10 10:22:37',
#   'Dixon-Love',
#   '2529 King Knoll Apt. 210 Michelleshire, NH 14266',
#   '55.0',
#   '5024.52',
#   '0',
#   '8.11',
#   '9.0'],
#  ['Brittany Martinez',
#   '2015-11-09 02:41:26',
#   'Ryan, Mcdonald and Garcia',
#   '4019 James Street Apt. 731 North Carmen, OK 01929',
#   '39.0',
#   '13029.61',
#   '1',
#   '4.83',
#   '8.0'],
#  ['Brittany Walker',
#   '2009-10-02 13:48:04',
#   'Trevino LLC',
#   '2835 Laura Cape West Sean, PR 08293',
#   '34.0',
#   '9779.12',
#   '0',
#   '5.89',
#   '9.0'],
#  ['Brittney Nichols',
#   '2012-01-17 00:39:22',
#   'Johnson, Mills and Murphy',
#   '85040 Denise Mills West Lynn, TN 21871',
#   '38.0',
#   '5353.97',
#   '0',
#   '6.25',
#   '9.0'],
#  ['Bruce Phillips',
#   '2015-05-28 12:14:03',
#   'Figueroa-Maynard',
#   'Unit 1895 Box 0949 DPO AA 40249',
#   '45.0',
#   '8771.02',
#   '1',
#   '6.64',
#   '11.0'],
#  ['Calvin Coleman',
#   '2013-07-09 16:29:09',
#   'Stark-Clarke',
#   'Unit 9127 Box 5819 DPO AE 24161',
#   '39.0',
#   '10388.38',
#   '0',
#   '5.1',
#   '7.0'],
#  ['Carla Ball',
#   '2016-12-28 04:07:38',
#   'Barton Inc',
#   '754 Shannon Mall South Shawn, AS 29886-0448',
#   '45.0',
#   '10793.11',
#   '1',
#   '4.65',
#   '10.0'],
#  ['Carla Patterson',
#   '2007-12-08 08:05:11',
#   'Pittman, Watts and Fitzgerald',
#   '350 Gregory Isle South Tinaland, WI 44398',
#   '58.0',
#   '12376.37',
#   '0',
#   '6.01',
#   '12.0'],
#  ['Carla Wolfe',
#   '2009-11-21 12:47:28',
#   'Ross Group',
#   '67507 Brittany Prairie Apt. 279 Solisborough, VA 81388-7017',
#   '48.0',
#   '7232.06',
#   '1',
#   '4.9',
#   '6.0'],
#  ['Carlos Miller',
#   '2015-03-08 08:03:14',
#   'Weaver Inc',
#   '506 Arnold Greens Apt. 335 South Kyleton, DC 78683',
#   '47.0',
#   '9004.44',
#   '0',
#   '3.79',
#   '8.0'],
#  ['Carol Johnston',
#   '2015-11-19 09:40:39',
#   'Lewis-Wilson',
#   '303 Brittany Landing Suite 749 Meghanmouth, TX 27021-4399',
#   '33.0',
#   '14160.05',
#   '1',
#   '4.61',
#   '7.0'],
#  ['Carolyn Cabrera',
#   '2012-08-09 19:53:53',
#   'Friedman-Smith',
#   '728 Sanders Centers Suite 047 Codyview, VI 66568',
#   '51.0',
#   '7810.06',
#   '0',
#   '5.99',
#   '9.0'],
#  ['Carrie Williams',
#   '2006-07-03 22:29:58',
#   'Tucker Inc',
#   '895 Miller Key Suite 001 Port Craigport, TX 36874',
#   '44.0',
#   '11597.38',
#   '0',
#   '3.45',
#   '7.0'],
#  ['Cassandra Proctor',
#   '2006-03-07 00:11:21',
#   'Smith, Moran and Gonzales',
#   '1780 Sherry Circle Ruizbury, WI 73815-9062',
#   '49.0',
#   '11321.2',
#   '0',
#   '4.89',
#   '10.0'],
#  ['Catherine Johnston',
#   '2006-07-06 02:38:21',
#   'Thomas, Marks and Hurst',
#   '590 Ware Mission East Markhaven, PR 46489',
#   '38.0',
#   '15509.97',
#   '0',
#   '4.65',
#   '8.0'],
#  ['Catherine Lucas',
#   '2009-05-18 15:10:36',
#   'Andrade-Cook',
#   '979 Joel Run Suite 561 Darlenetown, WA 27272',
#   '40.0',
#   '7837.67',
#   '1',
#   '5.66',
#   '11.0'],
#  ['Catherine Martin',
#   '2013-07-04 23:28:04',
#   'Lee Inc',
#   '75224 Powell Point Apt. 653 Lake Norma, AZ 05753',
#   '32.0',
#   '12142.99',
#   '0',
#   '5.01',
#   '7.0'],
#  ['Cathy Carney',
#   '2009-06-27 05:38:40',
#   'Carr and Sons',
#   '7816 Cynthia Unions Apt. 858 Elizabethhaven, KY 51905-4106',
#   '42.0',
#   '9261.41',
#   '0',
#   '3.92',
#   '9.0'],
#  ['Charles Ellison',
#   '2011-08-30 12:50:46',
#   'Mills Group',
#   '7082 Paul Divide Suite 132 New Nicolas, WI 35732',
#   '43.0',
#   '10746.69',
#   '0',
#   '8.62',
#   '9.0'],
#  ['Charles Mcgrath',
#   '2015-11-06 23:41:45',
#   'Adams-Gibbs',
#   '324 Krista Springs South Antoniohaven, ME 39849',
#   '42.0',
#   '6623.97',
#   '0',
#   '5.4',
#   '8.0'],
#  ['Charles Schultz',
#   '2015-09-22 23:07:05',
#   'Vargas and Sons',
#   'PSC 1774, Box 1074 APO AA 11178-4877',
#   '35.0',
#   '13035.91',
#   '1',
#   '5.51',
#   '6.0'],
#  ['Charles Thompson',
#   '2007-03-25 22:58:58',
#   'Sawyer and Sons',
#   '066 Jenkins Walks Barbaramouth, LA 76409',
#   '36.0',
#   '14003.88',
#   '1',
#   '3.54',
#   '6.0'],
#  ['Charles Whitney',
#   '2009-10-23 10:27:41',
#   'Christensen-Mccann',
#   '8006 Erin Pass Apt. 415 South Karen, LA 27331-0907',
#   '39.0',
#   '8667.02',
#   '0',
#   '6.82',
#   '10.0'],
#  ['Chelsea Marsh',
#   '2015-02-05 06:36:19',
#   'Wright-Olson',
#   '854 James Ranch Smithfort, WA 12954',
#   '41.0',
#   '9552.57',
#   '0',
#   '3.81',
#   '8.0'],
#  ['Chelsea Ward',
#   '2009-09-27 04:12:53',
#   'Hatfield, Johnson and George',
#   '5279 Grace Mountain Loriland, IL 83900',
#   '43.0',
#   '12104.25',
#   '0',
#   '5.86',
#   '7.0'],
#  ['Cheryl Bruce',
#   '2014-06-18 19:25:33',
#   'Oconnor, Hernandez and Bailey',
#   'PSC 5054, Box 2004 APO AP 20629',
#   '44.0',
#   '9613.84',
#   '1',
#   '4.38',
#   '8.0'],
#  ['Cheryl Hernandez',
#   '2010-02-18 18:40:00',
#   'Beltran Group',
#   '7772 Elizabeth Ridge North Chloe, AL 79941',
#   '46.0',
#   '4111.4',
#   '0',
#   '3.93',
#   '8.0'],
#  ['Chris Sutton',
#   '2016-06-22 19:20:04',
#   'Collins Ltd',
#   '858 Booth Points South Davidside, AZ 92136-1145',
#   '37.0',
#   '10314.67',
#   '1',
#   '5.86',
#   '8.0'],
#  ['Christian Mann',
#   '2008-03-10 01:30:38',
#   'Gallagher-Foster',
#   '53545 Susan Views Suite 594 New Pamela, OK 73980-0288',
#   '40.0',
#   '4762.81',
#   '1',
#   '5.12',
#   '10.0'],
#  ['Christina Farmer',
#   '2008-11-26 23:15:26',
#   'Gutierrez-Doyle',
#   '95806 Fuller Crossroad Suite 269 Lake Denise, VA 86649',
#   '44.0',
#   '9446.84',
#   '0',
#   '4.59',
#   '10.0'],
#  ['Christina Lewis',
#   '2014-01-03 00:55:23',
#   'Thompson, Shelton and Pena',
#   '273 Alexander Burg Suite 754 New Alexandrachester, DE 41261-1457',
#   '32.0',
#   '13630.93',
#   '0',
#   '4.38',
#   '10.0'],
#  ['Christina Maldonado',
#   '2006-08-28 11:16:01',
#   'Moreno, Green and Moreno',
#   '483 Douglas Club Apt. 632 Port Valerie, PW 88649-6413',
#   '49.0',
#   '9940.76',
#   '0',
#   '5.72',
#   '11.0'],
#  ['Christina Reed',
#   '2013-03-06 01:02:20',
#   'Atkins Group',
#   '53000 Mary Bypass New Markbury, IL 60012-4197',
#   '51.0',
#   '4523.91',
#   '0',
#   '3.98',
#   '8.0'],
#  ['Christine Jenkins',
#   '2008-12-15 20:01:27',
#   'English, King and Green',
#   '3542 Dawn Lane Williamchester, UT 01039',
#   '38.0',
#   '6574.25',
#   '0',
#   '6.18',
#   '9.0'],
#  ['Christopher Johnson',
#   '2006-10-26 00:50:30',
#   'Garcia-Moore',
#   '2804 Joel Station New Jennifer, DC 36785',
#   '46.0',
#   '7424.11',
#   '0',
#   '4.83',
#   '9.0'],
#  ['Christopher Martin',
#   '2011-09-01 16:47:27',
#   'Wise, Nichols and Allen',
#   '2910 Deborah Haven Apt. 221 Gomezstad, PW 18580-1005',
#   '39.0',
#   '9655.42',
#   '1',
#   '5.5',
#   '8.0'],
#  ['Christopher Price',
#   '2006-01-14 22:09:05',
#   'Porter-Johnson',
#   'PSC 8020, Box 7594 APO AE 50638',
#   '43.0',
#   '10598.35',
#   '1',
#   '6.72',
#   '8.0'],
#  ['Christopher Whitehead',
#   '2007-01-10 01:47:23',
#   'Harvey-Mckay',
#   '323 Farmer Cape Apt. 744 Jonathanfort, NJ 29387-2732',
#   '33.0',
#   '13314.19',
#   '0',
#   '5.45',
#   '9.0'],
#  ['Christopher Yates',
#   '2012-08-20 15:56:22',
#   'Hernandez, Middleton and Brewer',
#   'PSC 7127, Box 3035 APO AP 88800-1111',
#   '45.0',
#   '6452.83',
#   '1',
#   '4.41',
#   '6.0'],
#  ['Christy Hamilton',
#   '2009-08-14 22:27:57',
#   'Richard, Flores and Walsh',
#   '41390 Vazquez Mall Billystad, VI 57475-0791',
#   '45.0',
#   '9852.25',
#   '1',
#   '4.55',
#   '8.0'],
#  ['Cindy Marshall',
#   '2015-12-30 19:11:01',
#   'Gomez-Clarke',
#   '393 Stephens Field South Michelleside, MI 26930',
#   '37.0',
#   '9229.96',
#   '0',
#   '3.65',
#   '8.0'],
#  ['Claire Rivera',
#   '2016-05-24 04:02:24',
#   'Wade, Rowland and Jenkins',
#   '35166 Roberta Skyway Coreyfort, MO 59637-8470',
#   '48.0',
#   '13743.12',
#   '1',
#   '4.83',
#   '7.0'],
#  ['Cody Middleton',
#   '2010-04-14 22:03:19',
#   'Lawrence and Sons',
#   '86871 Jimenez Crest Suite 849 East Bruce, MO 68426-6342',
#   '36.0',
#   '11040.16',
#   '0',
#   '4.52',
#   '8.0'],
#  ['Cody Williams',
#   '2016-08-14 18:04:40',
#   'Farley, Clark and Peterson',
#   'USNS Lewis FPO AE 38853',
#   '38.0',
#   '11758.69',
#   '0',
#   '6.97',
#   '11.0'],
#  ['Connie Golden',
#   '2009-08-19 18:52:21',
#   'Brown-Wagner',
#   '3324 Gomez Knolls Suite 591 Farmerchester, LA 37647',
#   '39.0',
#   '10268.87',
#   '1',
#   '3.68',
#   '6.0'],
#  ['Connor Knapp',
#   '2015-09-21 16:18:10',
#   'Smith, Simpson and Wolf',
#   '7805 Kerri Route Marystad, UT 08020',
#   '41.0',
#   '9219.95',
#   '1',
#   '5.21',
#   '10.0'],
#  ['Craig Garner',
#   '2011-02-16 08:10:47',
#   'Abbott-Thompson',
#   '897 Kelley Overpass Suite 349 West Rebekahport, AZ 44793',
#   '45.0',
#   '8988.67',
#   '1',
#   '4.84',
#   '11.0'],
#  ['Cristian Sanchez',
#   '2006-05-10 17:23:08',
#   'Thornton and Sons',
#   '78444 Carla Ports Suite 763 Savagechester, IL 62536',
#   '44.0',
#   '10157.21',
#   '0',
#   '6.14',
#   '7.0'],
#  ['Crystal Smith',
#   '2014-01-28 07:38:46',
#   'Chan, Patterson and Smith',
#   '893 Carla Trace Suite 132 Lake Aliciaport, AR 87567',
#   '33.0',
#   '10309.71',
#   '1',
#   '2.96',
#   '7.0'],
#  ['Curtis Phillips',
#   '2011-07-21 16:04:43',
#   'Sweeney-Hall',
#   'Unit 6530 Box 3626 DPO AA 16636-7105',
#   '38.0',
#   '12978.81',
#   '0',
#   '7.94',
#   '7.0'],
#  ['Curtis Robinson',
#   '2006-01-28 01:22:53',
#   'Pearson-Gonzales',
#   '59027 Andrea Neck Apt. 438 North Makaylaside, OR 67470-1233',
#   '37.0',
#   '10565.59',
#   '0',
#   '4.76',
#   '10.0'],
#  ['Cynthia Burns',
#   '2007-08-30 07:15:35',
#   'Perez, Miller and Mcdowell',
#   'USCGC Gould FPO AP 18053-9165',
#   '47.0',
#   '12987.28',
#   '0',
#   '5.86',
#   '10.0'],
#  ['Cynthia Daniels',
#   '2007-09-06 18:15:23',
#   'Jackson-Terry',
#   '496 Klein Ports Quinnstad, NE 67656',
#   '31.0',
#   '8688.21',
#   '0',
#   '3.58',
#   '7.0'],
#  ['Cynthia Nguyen',
#   '2015-04-28 16:20:32',
#   'Sullivan-Weaver',
#   'PSC 5666, Box 1288 APO AE 26505',
#   '41.0',
#   '10054.6',
#   '1',
#   '4.93',
#   '6.0'],
#  ['Cynthia Norton',
#   '2016-01-19 15:31:15',
#   'Love-Jones',
#   '765 Tricia Row Karenshire, MH 71730',
#   '37.0',
#   '9191.58',
#   '0',
#   '5.56',
#   '9.0'],
#  ['Cynthia Wood',
#   '2014-05-24 05:29:40',
#   'Washington, Mcdaniel and Lambert',
#   '589 Mary Vista Lake Craig, CO 88641',
#   '49.0',
#   '12681.35',
#   '0',
#   '3.68',
#   '5.0'],
#  ['Dakota Porter',
#   '2007-08-23 19:38:19',
#   'Nguyen PLC',
#   '1005 Butler Manors Richardland, KS 45645-6252',
#   '41.0',
#   '7683.97',
#   '1',
#   '6.17',
#   '7.0'],
#  ['Dana Bailey',
#   '2015-11-08 06:57:18',
#   'Gibson, Frost and Rivera',
#   '61381 Cassandra Cliffs Apt. 605 West Frederickberg, PW 73455-0264',
#   '52.0',
#   '7077.34',
#   '1',
#   '5.6',
#   '8.0'],
#  ['Daniel Barton',
#   '2011-06-10 20:04:28',
#   'Davidson Group',
#   '551 Davis Crescent New Aliciaport, TX 94552-1600',
#   '44.0',
#   '9855.18',
#   '0',
#   '6.94',
#   '7.0'],
#  ['Daniel Bates',
#   '2008-09-13 11:53:42',
#   'Hunt PLC',
#   '488 Lewis Village Crawfordborough, WY 43563',
#   '30.0',
#   '10744.14',
#   '1',
#   '7.16',
#   '9.0'],
#  ['Daniel Brown',
#   '2016-02-12 22:38:03',
#   'Mosley Ltd',
#   '701 Alan Corners Port George, KY 15579-3799',
#   '51.0',
#   '4992.6',
#   '0',
#   '3.85',
#   '8.0'],
#  ['Daniel Thompson',
#   '2009-10-13 17:35:31',
#   'Maldonado-Goodwin',
#   '243 Laura Gateway Mitchellport, FL 53705-6256',
#   '33.0',
#   '7492.9',
#   '0',
#   '6.71',
#   '7.0'],
#  ['Daniel Todd',
#   '2013-06-19 11:25:41',
#   'Vega-Moss',
#   '7960 Ryan Circles Wilcoxhaven, ME 98912',
#   '37.0',
#   '9772.95',
#   '1',
#   '3.81',
#   '8.0'],
#  ['Daniel Washington',
#   '2013-05-14 16:58:55',
#   'Reeves-Scott',
#   '1537 Mccullough Canyon Rodriguezview, AZ 74625-8762',
#   '54.0',
#   '12147.83',
#   '1',
#   '4.17',
#   '8.0'],
#  ['Danielle Kirk',
#   '2007-07-31 06:39:54',
#   'Reeves-Curtis',
#   '20117 Johnson Ports Apt. 914 Jenniferfort, DC 40595',
#   '35.0',
#   '12403.81',
#   '0',
#   '4.42',
#   '11.0'],
#  ['Darlene Evans',
#   '2011-04-25 02:53:25',
#   'Dunlap and Sons',
#   '950 Christina Viaduct Anastad, IL 03324-2274',
#   '44.0',
#   '12721.55',
#   '0',
#   '5.18',
#   '11.0'],
#  ['Darren Brown',
#   '2010-05-28 21:29:01',
#   'Hall PLC',
#   '080 Amber Village Apt. 472 Schroederbury, AZ 32357',
#   '49.0',
#   '11584.59',
#   '1',
#   '4.84',
#   '6.0'],
#  ['Darren Chavez',
#   '2009-11-17 17:45:03',
#   'Hatfield, Lane and Solomon',
#   'PSC 5667, Box 8312 APO AP 00654',
#   '35.0',
#   '10166.67',
#   '0',
#   '4.65',
#   '10.0'],
#  ['David Allen',
#   '2010-04-21 15:26:30',
#   'Smith PLC',
#   '2900 Daniel Extension South Theodorefurt, OH 44883',
#   '35.0',
#   '10550.87',
#   '1',
#   '5.72',
#   '9.0'],
#  ['David Anderson',
#   '2008-07-04 02:41:59',
#   'Smith LLC',
#   '63410 Mark Rapids North Christopherbury, NV 91856-5125',
#   '39.0',
#   '11680.91',
#   '1',
#   '6.35',
#   '7.0'],
#  ['David Bowers',
#   '2009-04-09 00:38:23',
#   'Anthony, Walter and Moore',
#   '5737 Bowman Throughway Suite 494 Port Austinbury, AK 56390-6671',
#   '49.0',
#   '12893.19',
#   '0',
#   '5.13',
#   '7.0'],
#  ['David Compton',
#   '2013-07-08 17:40:46',
#   'Larsen PLC',
#   '292 John Course Apt. 691 Avilaburgh, ME 94092-4006',
#   '50.0',
#   '11294.45',
#   '1',
#   '2.17',
#   '10.0'],
#  ['David Grant',
#   '2009-11-11 23:33:43',
#   'Bryan, Small and Meyer',
#   '2974 Melvin Fords Suite 760 East Jacob, PR 90451-9722',
#   '45.0',
#   '13896.99',
#   '0',
#   '4.26',
#   '8.0'],
#  ['David Hernandez',
#   '2015-03-02 20:54:14',
#   'Lane and Sons',
#   '719 Kenneth Port Suite 911 New Micheal, GU 32134',
#   '36.0',
#   '12192.94',
#   '1',
#   '6.46',
#   '9.0'],
#  ['David Hess',
#   '2015-11-06 03:12:21',
#   'Johnson-Walker',
#   'PSC 1062, Box 1827 APO AA 46087-7414',
#   '41.0',
#   '5192.38',
#   '1',
#   '4.86',
#   '11.0'],
#  ['David Moore',
#   '2007-09-04 21:22:10',
#   'Harris, Carter and Brown',
#   'Unit 8071 Box 5003 DPO AE 63421-4620',
#   '40.0',
#   '7380.48',
#   '1',
#   '6.45',
#   '7.0'],
#  ['David Payne',
#   '2008-03-30 06:50:39',
#   'Aguirre LLC',
#   '882 Schneider Inlet Paigeburgh, NJ 33304',
#   '39.0',
#   '5914.3',
#   '1',
#   '2.3',
#   '9.0'],
#  ['David Rodriguez',
#   '2014-08-13 17:14:07',
#   'Walker-Baker',
#   '7318 Graham Ville Apt. 633 Gibsonview, MI 04337-6720',
#   '38.0',
#   '8642.01',
#   '1',
#   '4.76',
#   '11.0'],
#  ['David Sanders',
#   '2016-10-05 16:14:32',
#   'Wilson PLC',
#   'Unit 6283 Box 6735 DPO AP 09454-8286',
#   '41.0',
#   '8021.05',
#   '1',
#   '3.16',
#   '9.0'],
#  ['David Sweeney',
#   '2014-12-16 02:23:49',
#   'Adams, Dominguez and Vasquez',
#   '755 Ashley Motorway Suite 227 West Rachel, NH 67933-7552',
#   '34.0',
#   '7324.32',
#   '0',
#   '6.69',
#   '10.0'],
#  ['Dean Miller',
#   '2013-05-30 00:42:13',
#   'Parks-Bradley',
#   '803 Kelli Crossing Apt. 169 Jimenezberg, WV 56530-4240',
#   '41.0',
#   '9771.22',
#   '0',
#   '5.81',
#   '11.0'],
#  ['Deanna Henry',
#   '2010-03-29 20:16:38',
#   'Jones, Collins and Adams',
#   '62894 Summer Village Suite 944 Port Elizabeth, ID 67244-9988',
#   '47.0',
#   '6670.37',
#   '0',
#   '2.55',
#   '9.0'],
#  ['Deborah Howell',
#   '2006-08-18 05:47:20',
#   'Ortiz Ltd',
#   '9609 Harper Dale New Danieltown, AR 80238-4616',
#   '42.0',
#   '10583.76',
#   '0',
#   '6.51',
#   '9.0'],
#  ['Denise Watkins',
#   '2006-06-28 17:50:11',
#   'Price-Webb',
#   'PSC 9819, Box 2842 APO AE 04352-2576',
#   '47.0',
#   '9451.03',
#   '0',
#   '5.11',
#   '10.0'],
#  ['Derek Martinez',
#   '2011-08-29 06:35:54',
#   'Kramer PLC',
#   '3004 Nash Freeway North Craigville, CT 24488',
#   '40.0',
#   '11553.65',
#   '1',
#   '4.43',
#   '6.0'],
#  ['Derek Russell',
#   '2010-05-28 12:49:08',
#   'Hartman-Smith',
#   '2445 Jean Row Vasquezbury, RI 25867-8317',
#   '43.0',
#   '8817.29',
#   '0',
#   '3.19',
#   '8.0'],
#  ['Destiny Morales',
#   '2012-11-15 04:23:07',
#   'Martin, Flores and Graham',
#   '108 Oscar Rapids Port Vanessa, KY 23348-6290',
#   '40.0',
#   '8815.24',
#   '0',
#   '5.63',
#   '9.0'],
#  ['Destiny Steele',
#   '2010-11-13 11:16:01',
#   'Hall LLC',
#   '0784 Arnold Mountains Apt. 356 Thompsonview, IL 54999-9574',
#   '39.0',
#   '13532.85',
#   '1',
#   '5.63',
#   '9.0'],
#  ['Devin Cook',
#   '2015-02-05 11:35:45',
#   'Fleming LLC',
#   '237 Antonio Lock Lake Christianville, IN 42022',
#   '29.0',
#   '8688.17',
#   '1',
#   '5.7',
#   '9.0'],
#  ['Devin Wilson',
#   '2011-02-18 18:11:37',
#   'Cooke Ltd',
#   '97426 Carrie Stravenue East Cassandrafort, WV 23196',
#   '46.0',
#   '11222.48',
#   '0',
#   '4.92',
#   '9.0'],
#  ['Diana Carroll',
#   '2011-08-10 04:56:18',
#   'Rubio-Humphrey',
#   '3270 Barnes Station Suite 780 Lake Blake, TN 43554-9146',
#   '46.0',
#   '9601.95',
#   '0',
#   '5.9',
#   '9.0'],
#  ['Diana Jackson',
#   '2008-02-11 07:28:11',
#   'Stephens-Chavez',
#   'USNS Burnett FPO AA 61045',
#   '51.0',
#   '9879.37',
#   '0',
#   '3.55',
#   '10.0'],
#  ['Diane Terry',
#   '2007-10-15 03:45:59',
#   'Walton, Barnes and Simon',
#   '543 Bell Ranch Apt. 002 Kevinfurt, ID 14051-9447',
#   '53.0',
#   '13173.82',
#   '0',
#   '5.26',
#   '7.0'],
#  ['Dominique Kemp',
#   '2016-03-28 02:06:48',
#   'Richardson Inc',
#   '478 James Spurs North Thomas, MT 77158-1870',
#   '40.0',
#   '10370.72',
#   '1',
#   '4.35',
#   '5.0'],
#  ['Dominique Schneider',
#   '2007-08-07 06:00:00',
#   'Ford LLC',
#   '68378 Jeffrey Locks Apt. 678 Gibbsstad, OR 40474',
#   '43.0',
#   '12378.57',
#   '1',
#   '4.04',
#   '8.0'],
#  ['Donald Barrett',
#   '2014-01-14 10:48:37',
#   'Zhang-Brown',
#   '107 Melissa Manors Suite 419 East Teresashire, ME 40421-3419',
#   '51.0',
#   '10323.07',
#   '1',
#   '7.03',
#   '9.0'],
#  ['Donald Flores',
#   '2014-05-09 04:48:30',
#   'Harris-Pratt',
#   '30890 Gloria Oval Friedmanshire, OK 78837-9606',
#   '46.0',
#   '11580.56',
#   '1',
#   '3.43',
#   '9.0'],
#  ['Donna Good',
#   '2009-11-23 17:54:49',
#   'Alexander, Goodwin and Johnson',
#   'USNV Hill FPO AE 43418',
#   '37.0',
#   '12713.9',
#   '0',
#   '9.15',
#   '8.0'],
#  ['Doris Wilkins',
#   '2006-09-03 06:13:55',
#   'Andrews, Adams and Davis',
#   '28216 Wright Mount Apt. 356 Alichester, DE 40999-2369',
#   '45.0',
#   '8213.41',
#   '1',
#   '7.35',
#   '11.0'],
#  ['Doris Zimmerman',
#   '2015-03-10 20:16:40',
#   'Mitchell-Adams',
#   '3536 Rivera Springs Suite 771 New Marcusville, HI 22211-1439',
#   '40.0',
#   '11575.55',
#   '1',
#   '5.22',
#   '5.0'],
#  ['Douglas Joseph',
#   '2012-10-01 08:10:23',
#   'Clark PLC',
#   'Unit 9630 Box 8710 DPO AP 69319',
#   '44.0',
#   '8474.11',
#   '0',
#   '6.61',
#   '14.0'],
#  ['Douglas Lee',
#   '2012-03-29 02:43:19',
#   'Jensen, Morton and Edwards',
#   '088 Ayala Crossroad Lindafurt, MI 82946-5835',
#   '48.0',
#   '6783.99',
#   '1',
#   '3.89',
#   '8.0'],
#  ['Douglas Padilla',
#   '2008-04-28 01:11:37',
#   'Martinez Ltd',
#   '063 Andrew Harbor New Kathleenbury, AR 48898',
#   '38.0',
#   '10863.05',
#   '1',
#   '5.59',
#   '11.0'],
#  ['Dr. Brandon Adams',
#   '2013-06-22 06:20:23',
#   'Friedman-Carroll',
#   '93971 Jacob Flats Port Shannonton, IN 95823-2039',
#   '42.0',
#   '10500.77',
#   '0',
#   '5.68',
#   '6.0'],
#  ['Dr. Kathleen Wiley',
#   '2008-08-31 05:40:54',
#   'Clark Group',
#   '1615 Angela Valley Henryfurt, ID 45145-3704',
#   '45.0',
#   '8665.79',
#   '0',
#   '5.09',
#   '9.0'],
#  ['Dr. Michael Contreras',
#   '2016-08-22 05:47:48',
#   'Holt-Rogers',
#   '53891 Paula Corners Apt. 946 West Michael, ME 42796-1668',
#   '45.0',
#   '10364.82',
#   '0',
#   '5.93',
#   '5.0'],
#  ['Duane Mcdonald',
#   '2013-07-31 03:51:53',
#   'Armstrong-Hicks',
#   'USNV Nielsen FPO AA 31326',
#   '55.0',
#   '8280.03',
#   '0',
#   '6.33',
#   '5.0'],
#  ['Dwayne Ryan',
#   '2013-03-09 00:30:34',
#   'Williams and Sons',
#   '676 Carlos Port Apt. 925 Anitamouth, VA 05134-0836',
#   '39.0',
#   '10741.9',
#   '0',
#   '5.48',
#   '8.0'],
#  ['Edward Rhodes',
#   '2015-02-08 10:45:13',
#   'Walker and Sons',
#   '56573 Emily Falls Apt. 917 Simpsontown, VA 11466-4489',
#   '46.0',
#   '7876.84',
#   '1',
#   '6.41',
#   '10.0'],
#  ['Elizabeth Chandler',
#   '2006-04-15 03:59:33',
#   'Morris Inc',
#   'USNS Garcia FPO AA 23264-4875',
#   '43.0',
#   '13116.73',
#   '0',
#   '3.57',
#   '9.0'],
#  ['Emily Little',
#   '2015-05-06 23:55:35',
#   'Moore PLC',
#   '1779 Jessica Glen West Tylerport, VT 62988-2923',
#   '35.0',
#   '6683.82',
#   '1',
#   '7.82',
#   '7.0'],
#  ['Emily Roberson',
#   '2013-07-08 19:24:53',
#   'Clements-Summers',
#   '41199 Welch Stravenue Apt. 518 South Crystalshire, IA 58998-2407',
#   '36.0',
#   '12879.7',
#   '0',
#   '4.7',
#   '9.0'],
#  ['Eric Castro',
#   '2016-06-19 01:23:45',
#   'Campbell-Willis',
#   '80338 Scott Trail New Sandraview, WV 30882',
#   '38.0',
#   '10770.82',
#   '0',
#   '4.99',
#   '10.0'],
#  ['Eric Kelley',
#   '2011-07-19 10:28:53',
#   'Santos, Hoffman and Harper',
#   '98472 Meghan Mall Port Lauren, LA 49472',
#   '43.0',
#   '10271.19',
#   '1',
#   '5.31',
#   '14.0'],
#  ['Eric Lozano',
#   '2016-06-29 06:20:07',
#   'Miller, Johnson and Wallace',
#   '1331 Keith Court Alyssahaven, DE 90114',
#   '38.0',
#   '12884.75',
#   '0',
#   '6.67',
#   '12.0'],
#  ['Eric Martin',
#   '2006-05-31 09:24:41',
#   'Warner-Welch',
#   '162 Paul Freeway Apt. 301 New Jessicaton, SC 29138',
#   '44.0',
#   '14155.97',
#   '1',
#   '6.99',
#   '8.0'],
#  ['Eric Smith',
#   '2006-04-03 04:29:08',
#   'Thomas-Curtis',
#   '166 Julie Vista Apt. 132 Lake Sarahborough, HI 29875',
#   '37.0',
#   '11416.56',
#   '0',
#   '6.06',
#   '6.0'],
#  ['Eric Terry',
#   '2014-12-18 16:51:16',
#   'White-Thomas',
#   '2384 Lucero Trafficway Suite 201 Campbellchester, SD 24554-7364',
#   '42.0',
#   '16371.42',
#   '1',
#   '3.84',
#   '10.0'],
#  ['Erica Flores',
#   '2008-12-22 06:09:17',
#   'Carey Ltd',
#   '421 Kevin Shoal Grahamport, RI 11504',
#   '38.0',
#   '9624.18',
#   '0',
#   '5.53',
#   '12.0'],
#  ['Erik Johnson',
#   '2007-12-12 11:10:13',
#   'Lewis Group',
#   '6987 Weiss Flats Apt. 770 North Maria, MS 98836-9686',
#   '39.0',
#   '8986.28',
#   '0',
#   '4.36',
#   '8.0'],
#  ['Erik Martinez',
#   '2014-02-17 08:26:10',
#   'Martinez-Roberts',
#   '9780 Michelle Gateway Apt. 049 Lake Gabriellemouth, OK 06225',
#   '41.0',
#   '6535.91',
#   '0',
#   '4.83',
#   '11.0'],
#  ['Erin Gilbert',
#   '2014-08-06 19:11:10',
#   'Ware, Williams and Hill',
#   '7098 Vicki Lane Suite 339 South Dominic, NM 43022-5425',
#   '35.0',
#   '12357.31',
#   '0',
#   '5.03',
#   '10.0'],
#  ['Erin Hall',
#   '2009-02-21 05:30:35',
#   'Lawson-Carter',
#   '43775 Michael Curve Apt. 937 South Patricia, MN 13454-1801',
#   '41.0',
#   '13277.82',
#   '0',
#   '4.84',
#   '9.0'],
#  ['Erin Norris',
#   '2016-01-02 16:43:22',
#   'Garcia LLC',
#   '081 Randy Crest Apt. 821 South James, LA 27688-1775',
#   '37.0',
#   '15070.32',
#   '0',
#   '6.91',
#   '6.0'],
#  ['Erin Rivera',
#   '2016-11-06 01:13:12',
#   'Wilkins, White and Martin',
#   '34727 Randy Prairie Apt. 275 South Pamelashire, AS 63214-4216',
#   '37.0',
#   '8198.06',
#   '1',
#   '5.04',
#   '12.0'],
#  ['Eugene Robertson',
#   '2008-03-10 00:42:38',
#   'Miller-Wagner',
#   '87999 Knight Pine Apt. 281 Morenoland, ID 20602-9996',
#   '41.0',
#   '7464.08',
#   '0',
#   '3.74',
#   '8.0'],
#  ['Eugene Rowe',
#   '2015-06-23 09:54:27',
#   'Powell-Parker',
#   '45548 Henderson Islands Bakerside, WV 92882-7688',
#   '50.0',
#   '12941.12',
#   '1',
#   '5.51',
#   '11.0'],
#  ['Evan Davis',
#   '2011-09-14 19:09:29',
#   'Willis-Bradshaw',
#   '63845 Bell Mission Browninghaven, VA 72168',
#   '46.0',
#   '13296.89',
#   '1',
#   '4.81',
#   '6.0'],
#  ['Faith Sanchez',
#   '2009-06-26 18:06:47',
#   'Frazier and Sons',
#   '390 Johnson Glen Apt. 475 East Dawnbury, ME 42067',
#   '41.0',
#   '11738.88',
#   '0',
#   '7.27',
#   '9.0'],
#  ['Frances Jenkins',
#   '2015-01-03 18:57:56',
#   'Boyd-King',
#   '80428 Harris Islands Ethanfurt, CT 42032-8161',
#   '32.0',
#   '6367.22',
#   '1',
#   '2.84',
#   '10.0'],
#  ['Francisco Moore',
#   '2016-04-22 21:07:11',
#   'Carrillo-Potts',
#   '7433 Matthew Stream South Susan, NE 04017-0029',
#   '36.0',
#   '10345.19',
#   '1',
#   '4.84',
#   '10.0'],
#  ['Frank Chase',
#   '2006-01-05 11:26:28',
#   'Harvey, Thompson and Moss',
#   'USNS Potts FPO AA 56275',
#   '39.0',
#   '6168.66',
#   '1',
#   '4.71',
#   '8.0'],
#  ['Frank Coleman',
#   '2006-06-16 14:31:30',
#   'Pollard-Lambert',
#   '686 Bonnie Locks Suite 704 Hayesburgh, SD 23695-5265',
#   '39.0',
#   '4316.73',
#   '1',
#   '4.79',
#   '9.0'],
#  ['Frank Mann MD',
#   '2009-04-13 22:54:21',
#   'Carter, Johnson and Franklin',
#   '40205 Sellers Ville Apt. 983 Melanieview, DC 06529',
#   '43.0',
#   '8007.18',
#   '1',
#   '5.45',
#   '8.0'],
#  ['Garrett Walker',
#   '2013-10-09 13:57:29',
#   'Hunt-Jarvis',
#   '561 Michael Alley Robinsonmouth, WA 87560',
#   '42.0',
#   '8271.02',
#   '0',
#   '4.24',
#   '9.0'],
#  ['Gary Bryant',
#   '2010-07-21 16:56:35',
#   'Newman-Phillips',
#   '636 John Road Suite 304 Morrisonshire, MN 04090-3035',
#   '39.0',
#   '8646.2',
#   '0',
#   '2.94',
#   '9.0'],
#  ['Gary Odom',
#   '2009-01-15 17:39:15',
#   'Moran Inc',
#   '0349 Kimberly Ridges Michaelburgh, AK 08955',
#   '37.0',
#   '7982.38',
#   '1',
#   '4.29',
#   '8.0'],
#  ['Gerald Mullins',
#   '2009-06-04 17:54:25',
#   'Hamilton PLC',
#   '10282 Megan Island Port Carla, FM 85303-6406',
#   '42.0',
#   '8558.52',
#   '0',
#   '5.36',
#   '7.0'],
#  ['Gina Johnson',
#   '2008-03-25 15:58:18',
#   'Nguyen-Pratt',
#   '1975 Lawson Ford East Tylerchester, OK 01485',
#   '43.0',
#   '8261.89',
#   '0',
#   '7.36',
#   '9.0'],
#  ['Gina Richardson',
#   '2006-08-14 09:24:11',
#   'Murphy Inc',
#   '44577 John Keys Robertview, FL 73433-8410',
#   '33.0',
#   '13157.08',
#   '1',
#   '5.04',
#   '10.0'],
#  ['Greg Swanson',
#   '2013-02-20 19:36:40',
#   'Jackson-Garcia',
#   '446 Rodney Ridge Suite 282 West Williamside, MA 83236',
#   '44.0',
#   '11794.91',
#   '0',
#   '6.32',
#   '6.0'],
#  ['Gregory Chandler',
#   '2006-03-26 00:38:02',
#   'Gomez-Petersen',
#   '863 Marquez Brooks West Tommychester, MT 16982-2044',
#   '38.0',
#   '9419.66',
#   '1',
#   '5.24',
#   '9.0'],
#  ['Hailey Sanchez',
#   '2007-09-29 00:43:03',
#   'Evans-Wagner',
#   '78018 Ariana Crest Suite 467 North Tamara, IA 84527',
#   '41.0',
#   '14429.41',
#   '1',
#   '5.51',
#   '11.0'],
#  ['Hannah Best',
#   '2011-09-21 20:54:11',
#   'Cantrell-Paul',
#   'PSC 5882, Box 7573 APO AA 41758-4009',
#   '51.0',
#   '5830.99',
#   '0',
#   '6.93',
#   '6.0'],
#  ['Harold Griffin',
#   '2015-03-28 02:13:44',
#   'Snyder, Lee and Morris',
#   '1774 Peter Row Apt. 712 New Autumn, MT 18782',
#   '41.0',
#   '6569.87',
#   '1',
#   '4.3',
#   '11.0'],
#  ['Heather Daniel',
#   '2015-03-24 15:09:50',
#   'Martin, Dickerson and Roberson',
#   '25793 Phillips Cliff Travisview, WV 48402-6882',
#   '36.0',
#   '11274.98',
#   '0',
#   '4.12',
#   '10.0'],
#  ['Heather Figueroa',
#   '2007-06-27 02:09:55',
#   'Martin and Sons',
#   '945 Blankenship Plain Suite 062 East Christopherville, MI 15647-1190',
#   '36.0',
#   '12668.26',
#   '0',
#   '4.54',
#   '12.0'],
#  ['Heather Hernandez',
#   '2006-03-01 07:20:00',
#   'Carr, Esparza and Flores',
#   '6815 Andrea Isle Lindseyborough, OR 26077-2763',
#   '42.0',
#   '8519.64',
#   '0',
#   '3.99',
#   '8.0'],
#  ['Heather Hickman',
#   '2015-03-17 22:32:58',
#   'Moore LLC',
#   '7259 Brown Street Apt. 385 Monicaport, GU 05916-8374',
#   '31.0',
#   '11297.57',
#   '1',
#   '6.23',
#   '10.0'],
#  ['Heather Little',
#   '2009-09-24 01:06:30',
#   'Vaughan Group',
#   '158 Aaron Station Apt. 788 Millsport, VA 88018',
#   '33.0',
#   '4711.89',
#   '0',
#   '4.97',
#   '7.0'],
#  ['Heather Murphy',
#   '2015-12-30 18:49:35',
#   'Petersen, Howard and Bowen',
#   '1264 Williams Views Suite 114 Port Isaac, VI 31105-1539',
#   '46.0',
#   '12122.19',
#   '0',
#   '7.53',
#   '11.0'],
#  ['Heather Thompson',
#   '2014-01-30 10:39:34',
#   'Jacobs, Arnold and Schwartz',
#   '896 Lewis Wells Martinezstad, MO 12686',
#   '50.0',
#   '9248.87',
#   '0',
#   '4.56',
#   '9.0'],
#  ['Heidi Butler',
#   '2009-05-03 10:23:56',
#   'Gardner PLC',
#   '939 Elizabeth Tunnel Suite 840 Jamestown, MO 38646-5669',
#   '39.0',
#   '14425.74',
#   '0',
#   '5.91',
#   '6.0'],
#  ['Henry Cook',
#   '2009-12-08 00:18:10',
#   'Newton, Shepard and Berg',
#   '071 Michelle Green New Jasonview, AL 90525-9261',
#   '45.0',
#   '11486.53',
#   '1',
#   '5.5',
#   '7.0'],
#  ['Holly Caldwell',
#   '2014-10-29 11:21:21',
#   'Spencer, Young and Shaw',
#   '020 Amy Groves Suite 845 Phillipsport, AL 40594',
#   '37.0',
#   '11523.63',
#   '1',
#   '3.56',
#   '7.0'],
#  ['Holly Flores',
#   '2012-05-21 12:56:15',
#   'Reyes-Crawford',
#   '37362 Anthony Corner Suite 462 Port Saraton, ND 49109-1547',
#   '47.0',
#   '15878.11',
#   '1',
#   '2.05',
#   '8.0'],
#  ['Hunter Rivera',
#   '2014-12-18 19:58:36',
#   'Tate, Hall and Moreno',
#   '233 Mark Vista New Russellbury, FL 08810',
#   '26.0',
#   '8787.39',
#   '1',
#   '5.42',
#   '11.0'],
#  ['Isaiah Noble',
#   '2009-09-21 12:50:42',
#   'Taylor-Bradley',
#   '08820 Foster Via Suite 564 Barkerview, ME 82495-3527',
#   '44.0',
#   '10526.18',
#   '0',
#   '7.67',
#   '9.0'],
#  ['Jack Ortega',
#   '2009-06-09 07:44:13',
#   'Anderson-Evans',
#   '49625 Joseph Mountain West Brandon, AL 19037-8797',
#   '42.0',
#   '14242.7',
#   '0',
#   '5.79',
#   '10.0'],
#  ['Jacob Gutierrez',
#   '2007-08-17 09:17:57',
#   'Parrish LLC',
#   '8489 Christopher Circles Apt. 542 Sarahmouth, AL 61019-4480',
#   '40.0',
#   '11338.94',
#   '0',
#   '6.23',
#   '7.0'],
#  ['Jaime Padilla',
#   '2011-04-26 19:04:22',
#   'Richardson LLC',
#   '48403 Anderson Fields Apt. 103 New Jasonshire, NM 49852-3578',
#   '46.0',
#   '7684.02',
#   '1',
#   '6.24',
#   '8.0'],
#  ['James Adkins',
#   '2013-09-10 12:56:26',
#   'Taylor, Reynolds and Hoffman',
#   '2311 Henderson Centers Conniehaven, MP 16886-3947',
#   '35.0',
#   '8475.8',
#   '0',
#   '3.37',
#   '11.0'],
#  ['James Contreras',
#   '2008-12-08 09:23:02',
#   'Taylor-Robbins',
#   '10454 David Greens South Jenniferbury, FM 87283-5336',
#   '46.0',
#   '11119.11',
#   '1',
#   '3.51',
#   '14.0'],
#  ['James Evans',
#   '2013-01-16 16:29:49',
#   'Hughes Ltd',
#   '17140 Andrea Motorway Apt. 798 Amychester, WV 88972-7283',
#   '42.0',
#   '4492.44',
#   '1',
#   '6.43',
#   '9.0'],
#  ['James Hensley',
#   '2009-03-06 01:34:19',
#   'Leblanc-Torres',
#   '62940 Hill Alley Apt. 148 South Laurahaven, OR 94753-3273',
#   '46.0',
#   '8951.42',
#   '0',
#   '4.13',
#   '8.0'],
#  ['James Rivas',
#   '2007-01-10 07:29:46',
#   'Allen, Hernandez and Bryant',
#   '90866 Harmon Radial North Jennifermouth, MI 55389',
#   '38.0',
#   '9557.2',
#   '0',
#   '4.47',
#   '8.0'],
#  ['James Shah',
#   '2007-11-28 21:26:52',
#   'Wilson, Collins and Lee',
#   '66256 Danielle Ford New Maureen, MS 47550',
#   '47.0',
#   '9324.49',
#   '1',
#   '4.91',
#   '6.0'],
#  ['James Smith',
#   '2013-04-29 23:11:25',
#   'Cooper, Martin and Reid',
#   '6510 Debra Estates Port Lucasberg, NY 90239-6448',
#   '43.0',
#   '11375.25',
#   '1',
#   '5.09',
#   '9.0'],
#  ['James Wallace',
#   '2008-07-26 03:12:54',
#   'Williams, Huffman and Gibson',
#   '0613 Kidd Springs Apt. 467 Nicholasville, VI 42395',
#   '40.0',
#   '7762.73',
#   '1',
#   '4.66',
#   '10.0'],
#  ['Jamie Moore',
#   '2013-11-10 01:54:40',
#   'Herrera-Dodson',
#   '435 Hernandez Inlet Apt. 727 Josephfort, RI 51403',
#   '51.0',
#   '6114.85',
#   '1',
#   '4.7',
#   '9.0'],
#  ['Janet Hayden',
#   '2006-01-17 22:25:40',
#   'Bishop, Edwards and Webb',
#   '118 Linda Street Suite 025 Hunterberg, WA 50583',
#   '34.0',
#   '12813.91',
#   '0',
#   '2.41',
#   '7.0'],
#  ['Jason Hebert',
#   '2013-03-19 10:44:41',
#   'Hawkins-Escobar',
#   '26996 Nicole Ridge Suite 342 Lake Robertside, OK 04293',
#   '40.0',
#   '10606.97',
#   '1',
#   '4.11',
#   '10.0'],
#  ['Jason Phillips',
#   '2014-09-29 00:31:41',
#   'Davis-Bass',
#   '8928 Benjamin Summit Suite 264 North Samanthabury, AR 01364-7776',
#   '46.0',
#   '8418.81',
#   '1',
#   '7.19',
#   '6.0'],
#  ['Jason Santana',
#   '2011-09-30 06:15:01',
#   'Gonzalez LLC',
#   '8072 Kathy Harbors Apt. 845 Normanburgh, MA 46572-1532',
#   '39.0',
#   '9408.96',
#   '1',
#   '3.83',
#   '4.0'],
#  ['Jason Stevenson',
#   '2011-07-25 18:58:34',
#   'Cruz, Moore and Olsen',
#   '605 Stephen Glens Lake Juan, SD 28552',
#   '44.0',
#   '8580.85',
#   '0',
#   '5.52',
#   '10.0'],
#  ['Jason Taylor',
#   '2012-05-01 06:20:54',
#   'Moore, Nichols and Miller',
#   '693 Kevin Groves Apt. 158 Debramouth, NV 73809',
#   '46.0',
#   '5570.45',
#   '0',
#   '2.23',
#   '7.0'],
#  ['Jason West',
#   '2016-04-03 12:55:26',
#   'Santiago-Waller',
#   '6239 Timothy Overpass Carmenhaven, FM 05708-0772',
#   '45.0',
#   '13122.89',
#   '0',
#   '5.84',
#   '6.0'],
#  ['Jay Mosley',
#   '2015-05-05 10:00:10',
#   'Martinez, Gonzales and Williams',
#   '885 Samantha Estates Apt. 694 Michaelland, NC 35223',
#   '40.0',
#   '6402.3',
#   '0',
#   '4.28',
#   '7.0'],
#  ['Jeff Davis',
#   '2014-08-23 03:44:26',
#   'Klein, Dalton and Doyle',
#   '115 Andrews Vista South Kristinchester, SD 82774-5194',
#   '43.0',
#   '8583.5',
#   '1',
#   '4.39',
#   '10.0'],
#  ['Jeffery Ferguson',
#   '2011-12-22 17:51:38',
#   'Watts Ltd',
#   '1599 Rush Crescent Apt. 982 Bowmanchester, TX 33118-6129',
#   '32.0',
#   '12547.91',
#   '0',
#   '7.78',
#   '10.0'],
#  ['Jeffrey Hill',
#   '2006-09-22 20:58:51',
#   'Williams, Bautista and Carr',
#   '97907 Jensen Forge Brianmouth, MH 69993-8000',
#   '40.0',
#   '9922.3',
#   '1',
#   '5.07',
#   '11.0'],
#  ['Jeffrey Simpson',
#   '2006-02-15 12:09:15',
#   'Thompson, Vaughan and House',
#   '913 Thomas Dale Harristown, OR 05449-4141',
#   '42.0',
#   '7529.23',
#   '1',
#   '5.86',
#   '7.0'],
#  ['Jeffrey Thompson',
#   '2013-06-06 03:51:01',
#   'Peters, Rodriguez and Smith',
#   '7280 Douglas River Apt. 701 Suzanneport, KS 56534',
#   '42.0',
#   '6523.74',
#   '0',
#   '2.71',
#   '8.0'],
#  ['Jeffrey Trevino',
#   '2016-03-08 21:48:29',
#   'Price-Ramirez',
#   '0295 Mason Vista Suite 110 Ryanbury, IA 14087',
#   '37.0',
#   '13268.55',
#   '0',
#   '3.92',
#   '11.0'],
#  ['Jennifer Anderson',
#   '2015-12-15 11:48:35',
#   'Stewart, Sanchez and Valentine',
#   '521 Charles Lakes Lake Michaelland, NE 42708',
#   '38.0',
#   '11803.58',
#   '1',
#   '6.97',
#   '6.0'],
#  ['Jennifer Carrillo',
#   '2006-03-25 01:04:53',
#   'Ingram-Swanson',
#   '659 Robertson Lake Lake Peggy, CT 28993',
#   '35.0',
#   '12871.79',
#   '0',
#   '4.64',
#   '12.0'],
#  ['Jennifer Garcia',
#   '2007-11-16 01:02:38',
#   'Williams LLC',
#   '9071 Erickson Ridges Apt. 133 Glennberg, NE 87693',
#   '38.0',
#   '12913.55',
#   '1',
#   '4.73',
#   '7.0'],
#  ['Jennifer Hernandez',
#   '2010-08-23 13:43:19',
#   'Howe, Carpenter and Washington',
#   '1526 Jessica Corner Suite 592 Lindsayshire, OH 56989-0550',
#   '39.0',
#   '11159.46',
#   '0',
#   '3.95',
#   '11.0'],
#  ['Jennifer Lynch',
#   '2006-03-28 15:42:45',
# ...
#   '37.0',
#   '10989.43',
#   '0',
#   '6.62',
#   '10.0'],
#  ['Sarah Burns',
#   '2013-06-28 13:22:40',
#   'Frey-Burke',
#   '01740 Cynthia Rest Apt. 545 Bassburgh, MN 95437-1761',
#   '35.0',
#   '11814.59',
#   '0',
#   '5.89',
#   '6.0'],
#  ['Sarah Flores',
#   '2007-11-17 09:06:40',
#   'Cervantes, Rice and Strickland',
#   'USNV Morgan FPO AE 62096-4614',
#   '40.0',
#   '11527.08',
#   '1',
#   '5.04',
#   '8.0'],
#  ['Sarah Hall',
#   '2014-05-05 13:36:19',
#   'Sanchez-Brown',
#   '3930 Baker Square North Michaelside, PR 98680',
#   '45.0',
#   '5200.06',
#   '1',
#   '6.33',
#   '8.0'],
#  ['Sarah Holloway',
#   '2006-08-26 16:40:13',
#   'Harrison-Ferrell',
#   '099 Lopez Crescent Jamesport, OK 31273',
#   '45.0',
#   '8429.65',
#   '1',
#   '7.1',
#   '10.0'],
#  ['Sarah Morgan',
#   '2009-10-03 09:42:47',
#   'Braun-Cook',
#   '2458 Tyler Flats Suite 696 Rebeccaburgh, VA 79274',
#   '51.0',
#   '6662.59',
#   '1',
#   '5.27',
#   '9.0'],
#  ['Scott Chambers',
#   '2011-11-16 06:51:37',
#   'Davis, Cole and Thompson',
#   '9525 Allen Camp Apt. 362 West Dawnmouth, GA 04347',
#   '44.0',
#   '11424.0',
#   '1',
#   '5.98',
#   '10.0'],
#  ['Scott Love',
#   '2009-04-13 23:47:15',
#   'Williams-Johnson',
#   'Unit 7738 Box 0206 DPO AA 88767-0662',
#   '28.0',
#   '11128.95',
#   '1',
#   '5.12',
#   '8.0'],
#  ['Sean Macias',
#   '2006-07-02 23:47:33',
#   'Jimenez Group',
#   '911 Kent Point Anthonytown, KS 47499',
#   '47.0',
#   '11306.1',
#   '0',
#   '6.01',
#   '7.0'],
#  ['Seth Lopez',
#   '2007-07-10 15:33:56',
#   'Hodges LLC',
#   'Unit 2311 Box 4695 DPO AA 98374',
#   '44.0',
#   '11091.21',
#   '0',
#   '5.9',
#   '10.0'],
#  ['Shane Jones',
#   '2016-02-15 15:45:14',
#   'Wise Inc',
#   'PSC 2239, Box 8378 APO AA 67843',
#   '38.0',
#   '7713.12',
#   '1',
#   '5.41',
#   '9.0'],
#  ['Shannon Miller',
#   '2013-07-18 22:25:07',
#   'Nelson LLC',
#   '826 Ross Causeway Wardshire, ME 25891',
#   '35.0',
#   '7759.15',
#   '1',
#   '6.06',
#   '10.0'],
#  ['Sharon Hull',
#   '2007-11-09 16:04:00',
#   'Bradley-White',
#   'USCGC Collier FPO AE 40469-8677',
#   '37.0',
#   '11294.26',
#   '0',
#   '4.95',
#   '10.0'],
#  ['Shawn Chavez',
#   '2009-01-30 01:58:56',
#   'Carter, Murphy and Valenzuela',
#   '42028 Hampton Flat Apt. 206 North Samuelburgh, ME 73072',
#   '44.0',
#   '14036.28',
#   '1',
#   '7.25',
#   '10.0'],
#  ['Shawn Hughes',
#   '2009-03-16 00:10:13',
#   'Powell-Medina',
#   '89503 Hurley Wells Suite 603 Port Garrettmouth, MI 00879',
#   '52.0',
#   '5647.92',
#   '0',
#   '5.08',
#   '8.0'],
#  ['Shelia Phillips',
#   '2016-05-14 14:37:08',
#   'Norman-Holloway',
#   '451 David Vista Apt. 799 Danielsview, ND 69312',
#   '39.0',
#   '8644.07',
#   '1',
#   '4.48',
#   '8.0'],
#  ['Sonya Lewis',
#   '2015-09-19 12:58:19',
#   'Bowman, White and Shepherd',
#   '191 Timothy Villages Suite 755 New Jamestown, NY 42120-2598',
#   '48.0',
#   '9282.99',
#   '0',
#   '4.32',
#   '6.0'],
#  ['Stacey Harding',
#   '2007-12-22 13:07:46',
#   'Robinson-Koch',
#   '454 Sara Ways New Brandistad, AL 82361',
#   '39.0',
#   '11008.0',
#   '0',
#   '4.42',
#   '8.0'],
#  ['Stefanie Miranda',
#   '2007-09-12 16:27:24',
#   'Morrison-Pennington',
#   '002 Gutierrez Mountains Hayesburgh, GU 73502-4691',
#   '37.0',
#   '5039.46',
#   '0',
#   '4.08',
#   '8.0'],
#  ['Stephanie Gonzales',
#   '2014-01-13 05:18:56',
#   'Young-Dunn',
#   '437 Alex Glens Melindaburgh, ID 78010-8240',
#   '36.0',
#   '11550.29',
#   '0',
#   '6.46',
#   '13.0'],
#  ['Stephanie Juarez',
#   '2016-12-07 02:57:32',
#   'Gonzalez, Willis and Moody',
#   '026 Brown Springs Suite 306 Lindsayville, MD 06840',
#   '41.0',
#   '5191.08',
#   '0',
#   '6.29',
#   '7.0'],
#  ['Stephanie Martinez',
#   '2006-09-19 17:17:11',
#   'Nash, Grant and Chen',
#   '533 Smith Hills South Antonioview, WA 32566-3457',
#   '42.0',
#   '12975.35',
#   '1',
#   '4.47',
#   '7.0'],
#  ['Stephen Jenkins',
#   '2009-08-22 20:21:57',
#   'Everett-Taylor',
#   'USNV Perry FPO AE 07826-0914',
#   '30.0',
#   '12788.37',
#   '0',
#   '4.31',
#   '10.0'],
#  ['Steve Lewis',
#   '2014-06-12 12:47:15',
#   'Clarke-Gonzalez',
#   '865 Mitchell Causeway Suite 183 Meredithshire, AR 80502-3040',
#   '37.0',
#   '7961.21',
#   '0',
#   '2.91',
#   '9.0'],
#  ['Steven Blankenship',
#   '2011-03-28 01:58:13',
#   'Baker-Rios',
#   '2165 Williams Vista Apt. 849 South Colleen, GU 38418-9285',
#   '39.0',
#   '9848.4',
#   '1',
#   '6.73',
#   '10.0'],
#  ['Steven Hernandez',
#   '2015-04-05 15:57:24',
#   'Yates, Martinez and Cox',
#   '14609 Perez Turnpike Bradleyberg, DE 99755',
#   '54.0',
#   '8207.1',
#   '0',
#   '4.26',
#   '11.0'],
#  ['Steven Price',
#   '2011-04-05 07:23:43',
#   'Tran-Morris',
#   '586 Gregory Gateway Suite 935 Port Deborah, OK 46332',
#   '38.0',
#   '11227.39',
#   '1',
#   '5.71',
#   '9.0'],
#  ['Steven Stevenson',
#   '2013-10-17 21:48:30',
#   'George Inc',
#   '61756 Walls Ridges East James, IA 34568',
#   '52.0',
#   '7460.05',
#   '0',
#   '5.39',
#   '12.0'],
#  ['Summer Haley',
#   '2010-05-27 04:46:05',
#   'White, Vargas and Moore',
#   '312 Wilson Oval Suite 872 East Michaeltown, MN 40127-6212',
#   '43.0',
#   '12524.68',
#   '0',
#   '5.98',
#   '10.0'],
#  ['Sylvia Crawford',
#   '2009-07-23 06:05:22',
#   'Nguyen-Grant',
#   '032 Craig Lane Robertstown, AK 35233',
#   '47.0',
#   '7996.78',
#   '1',
#   '5.45',
#   '8.0'],
#  ['Sylvia Sherman',
#   '2010-09-27 05:53:21',
#   'Robinson PLC',
#   '451 Diaz Trafficway Mckinneymouth, AK 73479-7853',
#   '42.0',
#   '11783.81',
#   '1',
#   '5.27',
#   '7.0'],
#  ['Tabitha Love',
#   '2007-11-23 13:38:04',
#   'Stein PLC',
#   '8308 Rhodes Crest Apt. 745 Beckyfurt, KS 20974-1928',
#   '37.0',
#   '13498.28',
#   '1',
#   '7.06',
#   '9.0'],
#  ['Tamara Williams',
#   '2014-01-14 14:18:04',
#   'Tucker PLC',
#   '524 Taylor Lights Garrettfort, IA 35266',
#   '31.0',
#   '12264.68',
#   '1',
#   '5.88',
#   '8.0'],
#  ['Tammy Johnson',
#   '2008-07-23 06:09:07',
#   'Carr, Mills and Wilson',
#   '653 Smith Avenue South David, GA 19037',
#   '35.0',
#   '8828.59',
#   '0',
#   '6.77',
#   '9.0'],
#  ['Tammy Kelley',
#   '2014-07-20 09:42:45',
#   'Smith and Sons',
#   '41822 Wright Loop Apt. 718 West Kendrabury, CO 10948-4798',
#   '38.0',
#   '6638.87',
#   '1',
#   '5.61',
#   '8.0'],
#  ['Tammy Pope',
#   '2007-06-07 06:17:08',
#   'Hays, Henson and Shelton',
#   '9490 Kathryn Tunnel Suite 480 Shaneland, GA 26165-9694',
#   '45.0',
#   '9576.07',
#   '1',
#   '7.01',
#   '8.0'],
#  ['Tammy Reed',
#   '2007-10-09 18:07:48',
#   'Russo-Rivas',
#   '3067 Lindsay Road Apt. 683 Port Jonathan, NY 84626-8850',
#   '49.0',
#   '13173.8',
#   '1',
#   '6.36',
#   '12.0'],
#  ['Tammy Shepherd',
#   '2011-03-06 01:34:58',
#   'Martin Ltd',
#   '234 Gonzalez Terrace Santiagohaven, CO 28918-5500',
#   '48.0',
#   '11740.0',
#   '1',
#   '4.97',
#   '11.0'],
#  ['Tammy Williams',
#   '2009-12-13 18:17:02',
#   'Lawrence-Johnson',
#   '6720 Barbara Square Christopherchester, UT 54226',
#   '52.0',
#   '9065.28',
#   '0',
#   '3.99',
#   '5.0'],
#  ['Tasha Reed',
#   '2011-02-19 18:04:28',
#   'Price Group',
#   '575 Kara Shores Anthonyburgh, VT 30056',
#   '37.0',
#   '11912.13',
#   '0',
#   '5.67',
#   '10.0'],
#  ['Taylor Grant',
#   '2015-05-16 14:20:40',
#   'Barnett-Herrera',
#   'Unit 2836 Box 5288 DPO AP 28958-4427',
#   '39.0',
#   '10643.67',
#   '0',
#   '5.54',
#   '10.0'],
#  ['Teresa Bean',
#   '2007-02-14 00:56:53',
#   'Garza LLC',
#   '4962 Christian Squares North Belinda, OK 98156-7957',
#   '38.0',
#   '12020.62',
#   '0',
#   '4.41',
#   '8.0'],
#  ['Teresa Garcia',
#   '2012-09-20 05:52:41',
#   'Ibarra and Sons',
#   '2374 Jackson Walks Larryberg, PW 89438-7588',
#   '46.0',
#   '11343.33',
#   '1',
#   '3.69',
#   '8.0'],
#  ['Teresa Smith',
#   '2006-07-24 22:52:02',
#   'Villarreal-Ellis',
#   'USCGC Fleming FPO AA 06534-5672',
#   '45.0',
#   '7158.66',
#   '1',
#   '6.25',
#   '7.0'],
#  ['Teresa Thompson',
#   '2009-02-26 12:56:01',
#   'Snow, Martin and Fowler',
#   '762 Donald Field Suite 361 South Ronald, ME 08806',
#   '37.0',
#   '13036.52',
#   '1',
#   '3.83',
#   '6.0'],
#  ['Terry Curtis MD',
#   '2016-03-13 07:22:59',
#   'Blackburn-Bush',
#   '080 Jamie Way Cartermouth, MA 05582',
#   '48.0',
#   '8403.02',
#   '0',
#   '3.61',
#   '11.0'],
#  ['Terry Diaz',
#   '2014-06-30 15:46:07',
#   'Charles, Cruz and Marshall',
#   'USNV Rose FPO AP 67907-1654',
#   '46.0',
#   '11401.63',
#   '0',
#   '6.13',
#   '5.0'],
#  ['Terry Kelley',
#   '2013-02-25 23:36:03',
#   'Long-Williams',
#   'USCGC Lee FPO AE 62096-3283',
#   '37.0',
#   '9788.78',
#   '0',
#   '5.24',
#   '7.0'],
#  ['Theresa Ford',
#   '2015-01-19 23:48:25',
#   'Thornton Inc',
#   '9885 Mills Dale Suite 830 West Wendyton, WA 46448',
#   '40.0',
#   '9133.36',
#   '0',
#   '4.21',
#   '7.0'],
#  ['Theresa Martinez',
#   '2016-05-12 17:50:46',
#   'Howell-Valdez',
#   '21267 Nixon Coves Moorestad, NH 93322-8817',
#   '41.0',
#   '6204.86',
#   '1',
#   '6.08',
#   '8.0'],
#  ['Theresa Terry',
#   '2010-05-21 04:43:55',
#   'Campbell, Moore and Garrett',
#   '2927 Butler Keys Suite 851 West Christophermouth, MS 35752-5027',
#   '44.0',
#   '8819.13',
#   '1',
#   '4.38',
#   '10.0'],
#  ['Thomas Campbell',
#   '2006-09-13 04:18:55',
#   'Williams LLC',
#   'PSC 9216, Box 6338 APO AP 73140',
#   '36.0',
#   '8931.09',
#   '1',
#   '7.55',
#   '7.0'],
#  ['Thomas Mcintosh',
#   '2014-01-12 02:04:27',
#   'Garrett Ltd',
#   '510 Alexander Pike New Scottfort, NV 46217-8559',
#   '38.0',
#   '10026.44',
#   '1',
#   '6.85',
#   '9.0'],
#  ['Thomas Parker',
#   '2009-01-20 07:54:43',
#   'Cook LLC',
#   '10575 Jacob Manors Apt. 623 Port Jonathanview, WV 63831-0620',
#   '42.0',
#   '12277.9',
#   '1',
#   '5.1',
#   '8.0'],
#  ['Thomas Richardson',
#   '2014-10-11 14:08:10',
#   'Schmidt-Schroeder',
#   '8204 Leach Point Suite 900 Port Melissafort, TN 80024',
#   '44.0',
#   '10445.76',
#   '0',
#   '7.02',
#   '8.0'],
#  ['Thomas Rose',
#   '2012-08-18 09:16:47',
#   'Lynch, Padilla and Myers',
#   '9928 Lawson Court Andersonborough, KS 54353-7605',
#   '52.0',
#   '11849.13',
#   '0',
#   '6.8',
#   '11.0'],
#  ['Thomas Spears',
#   '2007-04-08 11:12:32',
#   'Chandler, Rivera and Fleming',
#   '5651 Ryan Roads Apt. 091 New Jenniferstad, OR 83943-6211',
#   '42.0',
#   '11654.34',
#   '0',
#   '5.06',
#   '10.0'],
#  ['Tiffany Case',
#   '2015-09-26 01:05:29',
#   'Clark Inc',
#   '0792 Denise Lodge Apt. 903 Jenniferchester, HI 96154-9657',
#   '42.0',
#   '7351.72',
#   '0',
#   '5.26',
#   '9.0'],
#  ['Timothy Brown',
#   '2015-09-27 20:20:08',
#   'Roberts, Delgado and Burch',
#   '7800 Riley Square Apt. 303 Jacquelineberg, HI 08954-7689',
#   '45.0',
#   '11187.93',
#   '1',
#   '4.95',
#   '9.0'],
#  ['Timothy Johnston',
#   '2010-03-29 17:41:53',
#   'Cole, Shelton and Atkinson',
#   '44906 Walker Plaza Sanchezshire, AK 41013-8944',
#   '41.0',
#   '12680.46',
#   '0',
#   '5.92',
#   '11.0'],
#  ['Tina King',
#   '2008-08-07 01:50:30',
#   'Franco-Jones',
#   '80203 Brandon Hill Apt. 353 New Luisport, VA 65076',
#   '40.0',
#   '8625.96',
#   '1',
#   '6.27',
#   '13.0'],
#  ['Tina Schmidt',
#   '2011-09-21 05:53:13',
#   'Hall Ltd',
#   '253 Megan Drive Apt. 447 Berryport, AL 03400-5942',
#   '45.0',
#   '10668.91',
#   '0',
#   '7.21',
#   '8.0'],
#  ['Todd Thompson',
#   '2008-10-19 09:18:12',
#   'Guzman, Johnson and Berry',
#   '2779 Dalton Ports New James, AS 59322-0419',
#   '38.0',
#   '12520.53',
#   '1',
#   '6.3',
#   '11.0'],
#  ['Tommy Frey',
#   '2008-01-06 09:57:34',
#   'Garcia-Owens',
#   '200 Craig Spur Suite 465 Wadeton, NC 47363',
#   '38.0',
#   '8825.87',
#   '1',
#   '8.97',
#   '10.0'],
#  ['Tony Boone',
#   '2006-04-18 10:56:21',
#   'Lopez-Nelson',
#   '1484 Carter Court Stephentown, FL 02705-7717',
#   '49.0',
#   '8232.11',
#   '0',
#   '6.84',
#   '8.0'],
#  ['Tony Mathews',
#   '2012-03-26 06:23:51',
#   'Navarro, Williams and Escobar',
#   '8471 Jason Spur Jasminemouth, AL 19070',
#   '47.0',
#   '9148.74',
#   '1',
#   '6.38',
#   '8.0'],
#  ['Tony Schneider',
#   '2009-04-30 13:55:51',
#   'Harper-Noble',
#   '329 Pierce Place Apt. 176 North Tammybury, WV 17594',
#   '43.0',
#   '11197.42',
#   '1',
#   '3.48',
#   '9.0'],
#  ['Tracy Jones',
#   '2011-08-01 01:56:09',
#   'Thompson, Bailey and Hernandez',
#   '417 Eric Overpass Williamfurt, MT 69664',
#   '39.0',
#   '6127.84',
#   '0',
#   '4.22',
#   '9.0'],
#  ['Travis Ellis',
#   '2010-10-20 00:12:32',
#   'Ramirez-Mendoza',
#   '730 Doris Drive Suite 569 Port Adam, KY 42352',
#   '46.0',
#   '12200.31',
#   '0',
#   '6.62',
#   '10.0'],
#  ['Travis Howell',
#   '2006-03-23 14:01:51',
#   'Schroeder-Phillips',
#   '946 Glass Cliffs Suite 105 Ashleemouth, GU 89701-5653',
#   '44.0',
#   '10585.86',
#   '0',
#   '5.54',
#   '8.0'],
#  ['Trevor Burns',
#   '2016-04-11 08:58:24',
#   'King LLC',
#   '2786 Collins Loaf Susanchester, CT 84620-3615',
#   '27.0',
#   '8628.8',
#   '1',
#   '5.3',
#   '7.0'],
#  ['Trevor Henderson',
#   '2010-04-14 20:39:00',
#   'Johnson-Rodriguez',
#   'USCGC Bailey FPO AA 06202-5064',
#   '47.0',
#   '9303.43',
#   '0',
#   '5.5',
#   '8.0'],
#  ['Troy Burke',
#   '2011-09-30 21:43:15',
#   'Austin LLC',
#   '2819 Wright Summit Nicholasmouth, CT 05051-3807',
#   '50.0',
#   '8193.77',
#   '0',
#   '5.13',
#   '8.0'],
#  ['Troy Ochoa',
#   '2012-05-01 12:42:04',
#   'Roberts-Schaefer',
#   '35985 Strong Islands South Kennethshire, LA 68247-0544',
#   '32.0',
#   '5756.12',
#   '0',
#   '5.9',
#   '8.0'],
#  ['Troy Oliver',
#   '2006-07-30 15:27:23',
#   'Gates Ltd',
#   'USCGC Blake FPO AA 66377-6894',
#   '40.0',
#   '10041.13',
#   '0',
#   '7.61',
#   '11.0'],
#  ['Vanessa Hayes',
#   '2010-06-24 21:15:32',
#   'Casey-Stevens',
#   '820 Kristin Lock Suite 348 Emilyhaven, WI 45502-8866',
#   '43.0',
#   '10944.65',
#   '1',
#   '2.62',
#   '9.0'],
#  ['Vanessa Hodge',
#   '2009-01-24 14:58:51',
#   'Li Ltd',
#   '29252 Powell Brook Suite 931 Port Scottland, MT 15769-3539',
#   '38.0',
#   '8370.15',
#   '0',
#   '8.6',
#   '5.0'],
#  ['Vanessa Myers',
#   '2011-09-27 06:52:13',
#   'Welch-Larsen',
#   '1150 Archer Point Suite 946 Marksfurt, MH 51860',
#   '39.0',
#   '13731.45',
#   '1',
#   '8.15',
#   '10.0'],
#  ['Vanessa Romero',
#   '2009-10-12 23:22:40',
#   'Smith, Wilson and Reeves',
#   '6571 Barbara Junctions Buckleychester, PA 35917-7024',
#   '44.0',
#   '12227.39',
#   '0',
#   '6.46',
#   '7.0'],
#  ['Victoria Medina',
#   '2012-10-24 02:46:36',
#   'Walters-Sanders',
#   '816 Jeremy Bridge Apt. 543 New Michelleville, VI 50678',
#   '43.0',
#   '11674.12',
#   '0',
#   '2.88',
#   '8.0'],
#  ['Victoria Shaffer',
#   '2015-08-06 02:01:43',
#   'Green LLC',
#   '2776 Maxwell Falls Lake Brian, MP 68585-6704',
#   '34.0',
#   '9919.38',
#   '0',
#   '4.43',
#   '8.0'],
#  ['Walter Bates',
#   '2012-08-10 09:19:49',
#   'Jones LLC',
#   '58605 Wiley Manor Apt. 796 Atkinstown, TX 41691',
#   '40.0',
#   '10180.59',
#   '1',
#   '6.5',
#   '10.0'],
#  ['Wanda Hess',
#   '2006-03-02 01:45:25',
#   'Mccarty-Stevens',
#   '3334 Alvarez Streets Apt. 358 Joyceton, MH 42340-8249',
#   '34.0',
#   '7818.13',
#   '0',
#   '6.11',
#   '8.0'],
#  ['Wayne Clark',
#   '2008-06-19 01:29:54',
#   'Brown-Coleman',
#   '72663 John Turnpike West Ryan, NY 72119-1924',
#   '43.0',
#   '6471.68',
#   '0',
#   '4.93',
#   '9.0'],
#  ['Wendy Moore',
#   '2011-05-28 08:09:09',
#   'Walker-Harris',
#   '8202 Jade Unions Suite 557 South Wesley, MS 12025',
#   '41.0',
#   '14722.35',
#   '0',
#   '6.98',
#   '6.0'],
#  ['Whitney Kennedy',
#   '2006-05-04 12:31:49',
#   'Bates-Underwood',
#   '6414 Jesus Knoll Apt. 139 Downsshire, VT 78464',
#   '42.0',
#   '10442.37',
#   '0',
#   '5.58',
#   '5.0'],
#  ['William Burns',
#   '2006-02-25 19:40:22',
#   'Santos, Hughes and Miller',
#   '432 Allen Station North Rebecca, MA 78424-2850',
#   '38.0',
#   '7673.0',
#   '1',
#   '7.42',
#   '7.0'],
#  ['William Newman',
#   '2011-10-07 15:43:59',
#   'Williams-Charles',
#   '3785 Duran Lodge Port Nicholashaven, MH 08892-1815',
#   '35.0',
#   '13680.25',
#   '1',
#   '5.79',
#   '9.0'],
#  ['William Pacheco',
#   '2008-03-11 20:48:20',
#   'Wilkerson-Miller',
#   'PSC 6149, Box 2267 APO AA 69767-2977',
#   '36.0',
#   '12086.92',
#   '1',
#   '5.52',
#   '6.0'],
#  ['Willie George II',
#   '2010-06-29 07:19:00',
#   'Murphy, Davis and Zimmerman',
#   'Unit 5118 Box 3795 DPO AA 27599',
#   '32.0',
#   '9036.27',
#   '0',
#   '7.14',
#   '11.0'],
#  ['Willie Proctor',
#   '2012-04-28 20:15:34',
#   'Schmidt Group',
#   '62726 Tracey Passage Apt. 685 South Brittany, RI 28461',
#   '47.0',
#   '8291.93',
#   '0',
#   '4.47',
#   '7.0'],
#  ['Yolanda Jackson',
#   '2009-07-30 07:28:06',
#   'Smith Group',
#   '7248 Wheeler Forks South Wendyport, KY 21877-0885',
#   '53.0',
#   '8122.34',
#   '0',
#   '3.51',
#   '9.0'],
#  ['Yvette Perry',
#   '2015-05-09 18:48:03',
#   'Moore and Sons',
#   '83457 Davis Flats Morachester, GU 52752',
#   '41.0',
#   '8560.76',
#   '1',
#   '3.99',
#   '12.0'],
#  ['Zachary Howard',
#   '2013-03-23 09:19:02',
#   'Peterson, Morgan and Wilson',
#   'PSC 9781, Box 0250 APO AP 24732',
#   '49.0',
#   '9000.36',
#   '0',
#   '4.13',
#   '11.0'],
#  ['Zachary Johnson',
#   '2006-11-05 12:19:57',
#   'Johnson-Conley',
#   '88565 Wright Loop East Kyle, AS 27859',
#   '28.0',
#   '8670.98',
#   '0',
#   '3.99',
#   '6.0'],
#  ['Zachary Sanchez',
#   '2011-04-27 00:14:40',
#   'Dawson-Porter',
#   '39704 Troy Pines Suite 887 South Amber, WI 13510',
#   '49.0',
#   '8131.64',
#   '1',
#   '7.1',
#   '7.0']]

# %%
lr = LogisticRegression()
lrModel = lr.fit(X_train.toPandas().values.tolist(), y_train.toPandas().values.tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-174-0707a0883a01> in <module>()
#       1 lr = LogisticRegression()
# ----> 2 lrModel = lr.fit(X_train.toPandas().values.tolist(), y_train.toPandas().values.tolist())
#
# /usr/local/lib/python3.6/dist-packages/pyspark/ml/base.py in fit(self, dataset, params)
#     120         if isinstance(params, (list, tuple)):
#     121             models = [None] * len(params)
# --> 122             for index, model in self.fitMultiple(dataset, params):
#     123                 models[index] = model
#     124             return models
#
# /usr/local/lib/python3.6/dist-packages/pyspark/ml/base.py in __next__(self)
#      60                 raise StopIteration("No models remaining.")
#      61             self.counter += 1
# ---> 62         return index, self.fitSingleModel(index)
#      63
#      64     def next(self):
#
# /usr/local/lib/python3.6/dist-packages/pyspark/ml/base.py in fitSingleModel(index)
#     101
#     102         def fitSingleModel(index):
# --> 103             return estimator.fit(dataset, paramMaps[index])
#     104
#     105         return _FitMultipleIterator(fitSingleModel, len(paramMaps))
#
# /usr/local/lib/python3.6/dist-packages/pyspark/ml/base.py in fit(self, dataset, params)
#     120         if isinstance(params, (list, tuple)):
#     121             models = [None] * len(params)
# --> 122             for index, model in self.fitMultiple(dataset, params):
#     123                 models[index] = model
#     124             return models
#
# /usr/local/lib/python3.6/dist-packages/pyspark/ml/base.py in __next__(self)
#      60                 raise StopIteration("No models remaining.")
#      61             self.counter += 1
# ---> 62         return index, self.fitSingleModel(index)
#      63
#      64     def next(self):
#
# /usr/local/lib/python3.6/dist-packages/pyspark/ml/base.py in fitSingleModel(index)
#     101
#     102         def fitSingleModel(index):
# --> 103             return estimator.fit(dataset, paramMaps[index])
#     104
#     105         return _FitMultipleIterator(fitSingleModel, len(paramMaps))
#
# /usr/local/lib/python3.6/dist-packages/pyspark/ml/base.py in fit(self, dataset, params)
#     130         else:
#     131             raise ValueError("Params must be either a param map or a list/tuple of param maps, "
# --> 132                              "but got %s." % type(params))
#     133
#     134
#
# ValueError: Params must be either a param map or a list/tuple of param maps, but got <class 'str'>.

# %% [markdown]
# 3.6. Evalúe los resultados en el conjunto de prueba. Muestre las primeras 5 predicciones.

# %% [markdown]
# 3.7. Para evaluar el desempeño del modelo, obtenga el valor del indicador auROC (área debajo de la curva ROC).

# %% [markdown]
# 3.8. Cargue los datos del archivo 'data_new.csv' y obtenga las predicciones sobre ese conjunto de datos utilizando los objetos construidos previamente. Muestre los primeros 5 elementos.

# %% [markdown]
# # Fin de la evaluación
