# %% [markdown]
# # [Portal datos abiertos ayuntamiento de Madrid](https://datos.madrid.es/portal/site/egob/)

# %% [markdown]
# # [Proyectos y Datos Metro Madrid](https://www.metromadrid.es/es/transparencia/proyectos-y-datos#panel1)

# %% [markdown]
# #[Open data EMT madrid](https://opendata.emtmadrid.es/Home)

# %% [markdown]
# # [Portal Abiertos CRTM](https://data-crtm.opendata.arcgis.com/)

# %% [markdown]
# # [Datos abiertos comunidad de madrid](https://datos.comunidad.madrid/catalogo/)

# %% [markdown]
# # [Datos gob](https://datos.gob.es/es)

# %% [markdown]
# #[Portal transparencia](https://transparencia.gob.es/)

# %% [markdown]
# # [Datos abiertos ESRI españa](https://opendata.esri.es/)

# %% [markdown]
# #[INE](https://www.ine.es/)

# %% [markdown]
# #[Datos Macro Expansion](https://datosmacro.expansion.com/)

# %% [markdown]
# #[Banco mundial datos](https://datos.bancomundial.org/)
